# %% [markdown]
# This notebook picks a bunch of healpix pixels, and renders a nice picture of it

# %%
from importlib import reload
import fitsio as fio
import numpy as np
import pandas as pd

import healpy as hp
import copy
import sys
import glob
import os
import matplotlib.pyplot as plt
# %matplotlib inline

import sklearn.decomposition as decomp


import matplotlib as mpl
import subprocess as sp
import scipy.interpolate as interpolate
import pickle as pickle
import glob
import healpy as hp
import images
import NFW

import astropy.cosmology as cosmology

import multiprocessing as mp

import galsim
import meds

import synthetic.tools as tools
import synthetic.emulator.emulator as emulator
import synthetic.emulator.indexer as indexer
import synthetic.emulator.reader as reader
import synthetic.render.frame as frame
import synthetic.render.render as render
import synthetic.mcal as mcal

# %%
folder_path = "/e/ocean1/users/vargatn/LSST/SYNTHETIC/"

# %%
in_path = "/e/ocean1/users/vargatn/LSST/DC2_1.1.4/"

# %%
fnames = glob.glob(in_path + "*pixel*h5")
pixels = np.array([int(tmp.split("-")[-1].split(".")[0]) for tmp in fnames])

# %%
pixel_id = 0

# %%
alltable = pd.read_hdf(fnames[pixel_id], key='data')
ra_cen = np.mean(alltable["ra"])
dec_cen = np.mean(alltable["dec"])

# %%
pad = 0.17 # degree
mag_max = 25

ii = (np.abs(alltable["ra"] - ra_cen) < pad) & (np.abs(alltable["dec"] - dec_cen) < pad) & (alltable['mag_i'] < mag_max)
table = alltable[ii]
ra = (table["ra"] - ra_cen) * 60. 
dec = (table["dec"] - dec_cen) * 60.

# %%
ra_cen, dec_cen
# Out:
# (50.64516228577292, -40.228830895890404)

# %% [markdown]
# # This is the pre injection canvas

# %%
pixel_scale = 0.264
mock_catalog = pd.DataFrame()
mock_catalog["RA"] = table["ra"]
mock_catalog["DEC"] = table["dec"]
mock_catalog["X"] = (table["ra"] - ra_cen) * 60 * 60 / pixel_scale + 2499.5
mock_catalog["Y"] = (table["dec"] - dec_cen) * 60 * 60 / pixel_scale + 2499.5

mock_catalog["MAG_I"] = table["mag_i"]
mock_catalog["TSIZE"] = table["size_true"]
mock_catalog["FRACDEV"] = 0
mock_catalog["FLUX_I"] = tools.toflux(table["mag_i"])
mock_catalog["G1"] = table["ellipticity_1_true"]
mock_catalog["G2"] = table["ellipticity_2_true"]

# %%
def make_mock(table, sky_center,  pixel_scale=0.264, image_offset=(2499.5, 2499.5)):
    pixel_scale = 0.264
    mock_catalog = pd.DataFrame()
    mock_catalog["RA"] = table["ra"]
    mock_catalog["DEC"] = table["dec"]
    mock_catalog["X"] = (table["ra"] - sky_center[0]) * 60 * 60 / pixel_scale + image_offset[0]
    mock_catalog["Y"] = (table["dec"] - sky_center[1]) * 60 * 60 / pixel_scale + image_offset[1]

    mock_catalog["MAG_G"] = table["mag_g"]
    mock_catalog["FLUX_G"] = tools.toflux(table["mag_g"])
    mock_catalog["MAG_R"] = table["mag_i"]
    mock_catalog["FLUX_R"] = tools.toflux(table["mag_r"])
    mock_catalog["MAG_I"] = table["mag_i"]
    mock_catalog["FLUX_I"] = tools.toflux(table["mag_i"])
    mock_catalog["MAG_Z"] = table["mag_z"]
    mock_catalog["FLUX_Z"] = tools.toflux(table["mag_z"])

    mock_catalog["TSIZE"] = table["size_true"]
    mock_catalog["FRACDEV"] = 0
    mock_catalog["G1"] = table["ellipticity_1_true"]
    mock_catalog["G2"] = table["ellipticity_2_true"]    
    return mock_catalog

def radec2xy(ra, dec, sky_center,  pixel_scale=0.264, image_offset=(2499.5, 2499.5)):
    x = (ra - sky_center[0]) * 60 * 60 / pixel_scale + image_offset[0]
    y = (dec - sky_center[1]) * 60 * 60 / pixel_scale + image_offset[1]
    return x.values, y.values

# %%
mock_catalog = make_mock(table, sky_center=(ra_cen, dec_cen))

# %%
len(table) / (0.1 * 60)**2.
# Out:
# 378.6666666666667

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)


ax.scatter(mock_catalog["X"], mock_catalog["Y"])

# %%
# stds = np.array([2.509813, 5.192254, 8.36335, 15.220351]) / 1.3
# for i, band in enumerate(("g", "r", "i")):
#     name = folder_path + 'test_canvas_grid_' + band
#     print(name)
#     fr = frame.Frame(mock_catalog.to_records(), band=band, name=name,
#                      center=(ra_cen, dec_cen), noise_std=stds[i], canvas_size=5000)
#     fr.render()

# %%
# ims_all = []
# for i, band in enumerate(("g", "r", "i")):
#     name = folder_path + 'test_canvas_grid_' + band + ".fits"
#     tmp = fio.read(name)
#     print(name)
#     ims_all.append(tmp)

# %%
# fig = plt.figure(figsize=(12, 12))
# ax = fig.add_subplot(111)
# factor = 0.01
# scales = np.array([1., 1.2, 2.5]) * factor
# nonlinear = 0.12
# clip = 0

# pad = 0
# obs_im = images.get_color_image(ims_all[2],# + ims_icl[2] + noises[2] + pad,
#                                 ims_all[1],# + ims_icl[1] + noises[1] + pad,
#                                 ims_all[0],# + ims_icl[0] + noises[0] + pad,
#                                 nonlinear=nonlinear, clip=clip, scales=scales)  
# print(obs_im.max())
# ax.imshow(obs_im * 2, origin='upper')

# # ax.set_title("cluster + field rendered together")

# ax.set_xlabel("X [pix]")
# ax.set_ylabel("Y [pix]")
# fig.savefig("dc2_hp.png", bbox_inches='tight')

# %% [markdown]
# Let's look at the most masive 10 halos in more detail

# %%
# ihmaxes = np.argsort(table["halo_mass"])[::-1]

# %%
# masses = table["halo_mass"][table["is_central"]].iloc[np.argsort(table["halo_mass"][table["is_central"]])[-10:]]
# ras = table["ra"][table["is_central"]].iloc[np.argsort(table["halo_mass"][table["is_central"]])[-10:]]
# decs = table["dec"][table["is_central"]].iloc[np.argsort(table["halo_mass"][table["is_central"]])[-10:]]
# xh, yh = radec2xy(ras, decs, sky_center=(ra_cen, dec_cen))

# %%
# marker_sizes = (np.log10(masses).values - 12.6) ** 4 * 30

# %%
# fig = plt.figure(figsize=(12, 12))
# ax = fig.add_subplot(111)
# factor = 0.01
# scales = np.array([1., 1.2, 2.5]) * factor
# nonlinear = 0.12
# clip = 0

# pad = 0
# obs_im = images.get_color_image(ims_all[2],# + ims_icl[2] + noises[2] + pad,
#                                 ims_all[1],# + ims_icl[1] + noises[1] + pad,
#                                 ims_all[0],# + ims_icl[0] + noises[0] + pad,
#                                 nonlinear=nonlinear, clip=clip, scales=scales)  
# print(obs_im.max())
# ax.imshow(obs_im * 2, origin='upper')
# ax.scatter(xh[::-1], yh[::-1], s=marker_sizes[::-1], color="white", marker="x")

# # ax.set_title("cluster + field rendered together")

# ax.set_xlabel("X [pix]")
# ax.set_ylabel("Y [pix]")
# fig.savefig("dc2_hp_halos_in_FOV.png", bbox_inches='tight')

# %% [markdown]
# # Making some normal strong Isothermal shears

# %%
cosmo = cosmology.FlatLambdaCDM(Om0=0.3, H0=70)

# %%
mock_catalog = make_mock(table, sky_center=(ra_cen, dec_cen))

xra = (mock_catalog['X'] - 2499.5) * 0.264 / 60 # arcmin
ydec = (mock_catalog['Y'] - 2499.5) * 0.264 / 60 # arcmin
dists = np.sqrt(xra**2 + ydec**2)
shears = np.sqrt(1 / dists  / 400) # just for illustration purposes
shears[shears > 0.8] = 0.8

phis =  np.arctan2(ydec, xra)
es1 = (-1. * shears * np.cos(2 * phis))
es2 = (-1. * shears * np.sin(2 * phis))
mock_catalog["G1"] = es1
mock_catalog["G2"] = es2

# dists = np.sqrt((mock_catalog["RA"] - ra_cen)**2 + (mock_catalog["DEC"] - dec_cen)**2)
# shears = np.sqrt(1 / (dists * 30)  / 3) # just for illustration purposes
# shears[shears > 0.8] = 0.8

# phis =  np.arctan2(mock_catalog["DEC"], mock_catalog["RA"])
# es1 = (-1. * shears * np.cos(2 * phis))
# es2 = (-1. * shears * np.sin(2 * phis))

# mock_catalog["G1"] = es1
# mock_catalog["G2"] = es2

# e1 = mock_catalog["G1"]
# e2 = mock_catalog["G2"]

# vals1 = e1 + es1 - e1 * es1 - e2 * es2
# vals2 = e2 + es2 - es1 * e2 + es2 * e1

# tmp = np.sqrt(vals1**2. + vals2**2.)
# ii = tmp > 0.95
# divs = 1. / (0.1 + tmp[ii])  
# vals1[ii] *= divs
# vals2[ii] *= divs

# mock_catalog["G1"] = vals1
# mock_catalog["G2"] = vals2

# %% [markdown]
# ## This is where we test the tangential shear profile

# %%
def get_tangential(xpos, ypos, e1, e2, center):
    """The center is where th aperture is"""
    dists = np.sqrt((ypos - center[1])**2. + (xpos - center[0])**2.)
    phis = np.arctan2(ypos - center[1], xpos - center[0])
    tshears = -e1 * np.cos(2 * phis) - e2 * np.sin(2 * phis)
    return tshears, dists

# %%
tshear, rarr = get_tangential(mock_catalog["X"], mock_catalog["Y"], es1, es2, (2499.5, 2499.5))

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# plot the truth curve
iorder = np.argsort(dists)
ax.plot(dists.iloc[iorder], shears.iloc[iorder], color="black", zorder=4, lw=3, label="true input e_t")
# ax.set_xscale("log")
# ax.set_yscale("log")
ax.set_xlabel("R [arcmin]", fontsize=14)
ax.set_ylabel("$\\gamma_t$", fontsize=14)
# Out:
# Text(0, 0.5, '$\\gamma_t$')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# plot the truth curve
iorder = np.argsort(dists)
ax.plot(dists.iloc[iorder], shears.iloc[iorder], color="black", zorder=4, lw=3, label="true input e_t")
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_xlabel("R [arcmin]", fontsize=14)
ax.set_ylabel("$\\gamma_t$", fontsize=14)
# Out:
# Text(0, 0.5, '$\\gamma_t$')

# %% [markdown]
# ## Rendering and detecting

# %%
stds = np.array([2.509813, 5.192254, 8.36335, 15.220351]) / 1.3
for i, band in enumerate(("g", "r", "i")):
    name = folder_path + 'test_canvas_grid_low-isothermal_' + band
    print(name)
    fr = frame.Frame(mock_catalog.to_records(), band=band, name=name,
                     center=(ra_cen, dec_cen), noise_std=stds[i], canvas_size=5000)
    fr.render()
# Out:
# /e/ocean1/users/vargatn/LSST/SYNTHETIC/test_canvas_grid_low-isothermal_g
# starting postage stamp calculations in 100 processes
# /e/ocean1/users/vargatn/LSST/SYNTHETIC/test_canvas_grid_low-isothermal_r
# starting postage stamp calculations in 100 processes
# /e/ocean1/users/vargatn/LSST/SYNTHETIC/test_canvas_grid_low-isothermal_i
# starting postage stamp calculations in 100 processes

# %%
ims_all = []
for i, band in enumerate(("g", "r", "i")):
    name = folder_path + 'test_canvas_grid_low-isothermal_' + band + ".fits"
    tmp = fio.read(name)
    print(name)
    ims_all.append(tmp)
# Out:
# /e/ocean1/users/vargatn/LSST/SYNTHETIC/test_canvas_grid_low-isothermal_g.fits
# /e/ocean1/users/vargatn/LSST/SYNTHETIC/test_canvas_grid_low-isothermal_r.fits
# /e/ocean1/users/vargatn/LSST/SYNTHETIC/test_canvas_grid_low-isothermal_i.fits

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
factor = 0.01
scales = np.array([1., 1.2, 2.5]) * factor
nonlinear = 0.12
clip = 0

pad = 0
obs_im = images.get_color_image(ims_all[2],# + ims_icl[2] + noises[2] + pad,
                                ims_all[1],# + ims_icl[1] + noises[1] + pad,
                                ims_all[0],# + ims_icl[0] + noises[0] + pad,
                                nonlinear=nonlinear, clip=clip, scales=scales)  
print(obs_im.max())
ax.imshow(obs_im[2000:3000, 2000:3000] * 2, origin='upper')

# ax.set_title("cluster + field rendered together")

ax.set_xlabel("X [pix]")
ax.set_ylabel("Y [pix]")
fig.savefig("dc2_hp_low-isothermal.png", bbox_inches='tight')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 0.866536557674408

# %% [markdown]
# ## Render a deeper mock coadd and run sextractor

# %%
name = folder_path + 'test_canvas_grid_low-isothermal_coadd_' + 'i'
print(name)
fr = frame.Frame(mock_catalog.to_records(), band=band, name=name,
                     center=(ra_cen, dec_cen), noise_std=1., canvas_size=5000)
fr.render() 
fr.extract()
# Out:
# /e/ocean1/users/vargatn/LSST/SYNTHETIC/test_canvas_grid_low-isothermal_coadd_i
# starting postage stamp calculations in 100 processes
# sex /e/ocean1/users/vargatn/LSST/SYNTHETIC/test_canvas_grid_low-isothermal_coadd_i.fits -c config.sex -CATALOG_NAME /e/ocean1/users/vargatn/LSST/SYNTHETIC/test_canvas_grid_low-isothermal_coadd_i_cat.fits -CHECKIMAGE_NAME /e/ocean1/users/vargatn/LSST/SYNTHETIC/test_canvas_grid_low-isothermal_coadd_i_seg.fits

# %%
# noise = np.random.normal(scale=fr.noise_std, size=(fr.canvas_size, fr.canvas_size))
noise = np.ones(shape=(fr.canvas_size, fr.canvas_size))
wcanvas = galsim.ImageF(noise, wcs=fr.canvas.wcs)
wcanvas.write(name + '_weight.fits', clobber=True)

# %% [markdown]
# # Create MEDS file

# %%
ii = fr.scat["MAG_AUTO"] < 23
objects = fr.scat[ii]

# %%
nimage = 1
nobj = len(objects)
obj_data = meds.util.get_meds_input_struct(nobj, extra_fields=[("X_IMAGE", "f8"), ("Y_IMAGE", "f8")])
obj_data['id'] = objects['NUMBER']

box_sizes = np.round(objects["A_IMAGE"] * objects["B_IMAGE"] * 2 ) *2
box_sizes[box_sizes < 16] = 16
obj_data['box_size'] = box_sizes

obj_data['ra'] = objects['ALPHAWIN_J2000'] + 0.264 / 3600 # this is a hack for fortran vs python ordered arrays
obj_data['dec'] = objects['DELTAWIN_J2000'] - 0.264 / 3600
obj_data['X_IMAGE'] = objects['X_IMAGE']
obj_data['Y_IMAGE'] = objects['Y_IMAGE']

# %%
path_image = name + ".fits"
path_weight = name + "_weight.fits"
path_seg = name + "_seg.fits"

path_length= np.max((len(path_image), len(path_seg), len(path_weight)))

image_info= meds.util.get_image_info_struct(nimage, path_length)

image_info['image_path'][0] = path_image
image_info['weight_path'][0] = path_weight
image_info['seg_path'][0] = path_seg
image_info['magzp'] = 30.

config = {'first_image_is_coadd': False,'cutout_types':['weight', 'seg'],'psf_type':'psfex'}

# %%
import psfex

# row=514.25
# col=610.00
pex = psfex.PSFEx("../meds/star_canvas_cat.psf")
# image = pex.get_rec(row, col)
psf_data = [pex,]
# psf_data = [mpex]

# %%
mm = meds.MEDSMaker(obj_data=obj_data, image_info=image_info, config=config, psf_data=psf_data)
mm.write(folder_path + "canvas_grid_low-isothermal.meds")
# Out:
# writing cutouts for: ['image', 'weight', 'seg']
# file    1 of    1: 'b'/e/ocean1/users/vargatn/LSST/SYNTHETIC/test_canvas_grid_low-isothermal_coadd_i.fits''
#     first cut:    2877 of   2877 objects
#     second cut:   2877 of   2877 objects
# 2877/2877 had ncut > 0
# setting start rows and pixel count
# total pixels: 4220244
# setting psf layout for PSFEx
# meds layout build time: 0.175619 seconds
# opening output MEDS file: '/e/ocean1/users/vargatn/LSST/SYNTHETIC/canvas_grid_low-isothermal.meds'
# writing object_data
# writing image_info
# writing metadata
#     reserving image mosaic
#     reserving weight mosaic
# /home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/site-packages/meds/util.py:380: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   phat = numpy.array([-1.0*sinp,cosp,0.0]).T
#     reserving seg mosaic
#     reserving psf mosaic
# writing image cutouts
#     1/1 image b'/e/ocean1/users/vargatn/LSST/SYNTHETIC/test_canvas_grid_low-isothermal_coadd_i.fits'
#     no background for image
# writing weight cutouts
#     1/1 weight b'/e/ocean1/users/vargatn/LSST/SYNTHETIC/test_canvas_grid_low-isothermal_coadd_i_weight.fits'
# writing seg cutouts
#     1/1 seg b'/e/ocean1/users/vargatn/LSST/SYNTHETIC/test_canvas_grid_low-isothermal_coadd_i_seg.fits'
# writing psf cutouts
# output is in: /e/ocean1/users/vargatn/LSST/SYNTHETIC/canvas_grid_low-isothermal.meds

# %%
m = meds.MEDS(folder_path + "canvas_grid_low-isothermal.meds")

# %%
im = m.get_cutout(1623, 0, 'image')
fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(im)

# %% [markdown]
# # Running metacal

# %%
input_name = folder_path + "canvas_grid_low-isothermal.meds"

# %%
outfile_names = folder_path + "canvas_grid_low-isothermal_mcal" # file name root of output (will have additional _01 _02 etc appended to it)
maxnum = len(objects) # The highest number of  objects to include from the sextractor detection catalog. 


infodicts = mcal.infomaker(maxnum, input_name, outfile_names, nchunk=100)

# %%
mcal.multi_mcal(infodicts, nprocess=100)
# Out:
# starting metacal calculations in 100 processes
# Total fitting and stacking time: 29.46837568283081 seconds
# Total fitting and stacking time: 30.20957040786743 seconds
# Total fitting and stacking time: 30.407718658447266 seconds
# Total fitting and stacking time: 30.55513048171997 seconds
# Total fitting and stacking time: 30.62501811981201 seconds
# Total fitting and stacking time: 30.679884910583496 seconds
# Total fitting and stacking time: 30.7668399810791 seconds
# Total fitting and stacking time: 30.89032292366028 seconds
# Total fitting and stacking time: 30.89739489555359 seconds
# Total fitting and stacking time: 31.037548065185547 seconds
# Total fitting and stacking time: 31.41431498527527 seconds
# Total fitting and stacking time: 31.738659858703613 seconds
# Total fitting and stacking time: 31.91551184654236 seconds
# Total fitting and stacking time: 31.964980125427246 seconds
# Total fitting and stacking time: 32.012101888656616 seconds
# Total fitting and stacking time: 32.08082818984985 seconds
# Total fitting and stacking time: 32.101715326309204 seconds
# Total fitting and stacking time: 32.194727182388306 seconds
# Total fitting and stacking time: 32.22792291641235 seconds
# Total fitting and stacking time: 32.266244888305664 seconds
# Total fitting and stacking time: 32.483874797821045 seconds
# Total fitting and stacking time: 32.58987307548523 seconds
# Total fitting and stacking time: 32.78888559341431 seconds
# Total fitting and stacking time: 32.80505681037903 seconds
# Total fitting and stacking time: 32.8940634727478 seconds
# Total fitting and stacking time: 32.91856050491333 seconds
# Total fitting and stacking time: 32.97217917442322 seconds
# Total fitting and stacking time: 33.090521574020386 seconds
# Total fitting and stacking time: 33.10444521903992 seconds
# Total fitting and stacking time: 33.10240411758423 seconds
# Total fitting and stacking time: 33.11997318267822 seconds
# Total fitting and stacking time: 33.54892373085022 seconds
# Total fitting and stacking time: 33.59361553192139 seconds
# Total fitting and stacking time: 33.664259910583496 seconds
# Total fitting and stacking time: 33.701085567474365 seconds
# Total fitting and stacking time: 33.886035680770874 seconds
# Total fitting and stacking time: 33.91917848587036 seconds
# Total fitting and stacking time: 33.980701208114624 seconds
# Total fitting and stacking time: 34.00867772102356 seconds
# Total fitting and stacking time: 34.01070976257324 seconds
# Total fitting and stacking time: 34.16566228866577 seconds
# Total fitting and stacking time: 34.25665283203125 seconds
# Total fitting and stacking time: 34.4290509223938 seconds
# Total fitting and stacking time: 34.63961672782898 seconds
# Total fitting and stacking time: 34.637202978134155 seconds
# Total fitting and stacking time: 34.72577667236328 seconds
# Total fitting and stacking time: 35.138805866241455 seconds
# Total fitting and stacking time: 35.17120981216431 seconds
# Total fitting and stacking time: 35.158034324645996 seconds
# Total fitting and stacking time: 35.23842787742615 seconds
# Total fitting and stacking time: 35.450512170791626 seconds
# Total fitting and stacking time: 35.59945726394653 seconds
# Total fitting and stacking time: 35.91613960266113 seconds
# Total fitting and stacking time: 36.12299346923828 seconds
# Total fitting and stacking time: 36.55084538459778 seconds
# Total fitting and stacking time: 36.54184436798096 seconds
# Total fitting and stacking time: 36.594878911972046 seconds
# Total fitting and stacking time: 36.60182499885559 seconds
# Total fitting and stacking time: 36.73354172706604 seconds
# Total fitting and stacking time: 36.737619161605835 seconds
# Total fitting and stacking time: 36.773216009140015 seconds
# Total fitting and stacking time: 36.80255484580994 seconds
# Total fitting and stacking time: 36.815807580947876 seconds
# Total fitting and stacking time: 36.85515999794006 seconds
# Total fitting and stacking time: 36.88813400268555 seconds
# Total fitting and stacking time: 36.87366080284119 seconds
# Total fitting and stacking time: 36.883625745773315 seconds
# Total fitting and stacking time: 37.05694246292114 seconds
# Total fitting and stacking time: 37.23126840591431 seconds
# Total fitting and stacking time: 37.22831344604492 seconds
# Total fitting and stacking time: 37.45206069946289 seconds
# Total fitting and stacking time: 37.50547814369202 seconds
# Total fitting and stacking time: 37.59638547897339 seconds
# Total fitting and stacking time: 37.684842348098755 seconds
# Total fitting and stacking time: 37.7448787689209 seconds
# Total fitting and stacking time: 37.77160120010376 seconds
# Total fitting and stacking time: 37.766218423843384 seconds
# Total fitting and stacking time: 38.138150215148926 seconds
# Total fitting and stacking time: 38.19712591171265 seconds
# Total fitting and stacking time: 38.187230825424194 seconds
# Total fitting and stacking time: 38.23184275627136 seconds
# Total fitting and stacking time: 38.247365951538086 seconds
# Total fitting and stacking time: 38.43189978599548 seconds
# Total fitting and stacking time: 38.567471742630005 seconds
# Total fitting and stacking time: 38.63706874847412 seconds
# Total fitting and stacking time: 38.70482039451599 seconds
# Total fitting and stacking time: 38.72761082649231 seconds
# Total fitting and stacking time: 38.801209926605225 seconds
# Total fitting and stacking time: 38.86022973060608 seconds
# Total fitting and stacking time: 38.9256432056427 seconds
# Total fitting and stacking time: 38.99015259742737 seconds
# Total fitting and stacking time: 39.15347719192505 seconds
# Total fitting and stacking time: 39.211320877075195 seconds
# Total fitting and stacking time: 39.27056360244751 seconds
# Total fitting and stacking time: 39.304091930389404 seconds
# Total fitting and stacking time: 39.51843547821045 seconds
# Total fitting and stacking time: 39.872222900390625 seconds
# Total fitting and stacking time: 39.907557010650635 seconds
# Total fitting and stacking time: 40.11957597732544 seconds
# Total fitting and stacking time: 40.88163733482361 seconds

# %%
tab = mcal.collater(infodicts)

# %%
tshear, rarr = get_tangential(tab["X_IMAGE"], tab["Y_IMAGE"],
                              tab["g_noshear"][:, 0], tab["g_noshear"][:, 1],
                              (2499.5, 2499.5))
rarr *= pixel_scale / 60

# %%
resp = (tab["r11"] + tab["r22"]) / 2

# %%
def binned_signal(rvals, shears, redges, resps=None):
    
    rcens = redges[:-1] + np.diff(redges) / 2.
    vals = np.zeros(len(rcens))
    vals_err = np.zeros(len(rcens)) # This is the error on the mean, not the std
    respvals = np.zeros(len(rcens))
    for i, tmp in enumerate(redges[:-1]):
        ii = np.where((rvals > redges[i]) & (rvals < redges[i + 1]))[0]
        vals[i] = np.mean(shears[ii])
        vals_err[i] = np.std(shears[ii]) / np.sqrt(len(ii))
        
        if resps is not None:
            respvals[i] = np.mean(resps[ii])
            
    return rcens, vals, vals_err, respvals

# %%
binned_signal(rarr, tshear, np.linspace(0, 14, 10), resp)
# Out:
# (array([ 0.77777778,  2.33333333,  3.88888889,  5.44444444,  7.        ,
#          8.55555556, 10.11111111, 11.66666667, 13.22222222]),
#  array([0.033189  , 0.0190172 , 0.03037177, 0.02516379, 0.01922644,
#         0.00864661, 0.00848275, 0.02565989, 0.00646168]),
#  array([0.00921843, 0.0052894 , 0.005628  , 0.00535719, 0.00501303,
#         0.00353368, 0.00354275, 0.00692816, 0.00788917]),
#  array([0.95926844, 0.98872816, 1.06715384, 1.00442295, 0.99771729,
#         0.95963474, 1.0170585 , 0.92973043, 0.96663801]))

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

# plot the truth curve
iorder = np.argsort(dists)
ax.plot(dists.iloc[iorder], shears.iloc[iorder], color="black", zorder=4, lw=3, label="true input e_t")

redges = np.linspace(0, 14, 10)
rcens, strue, tmp = binned_signal(dists.iloc[iorder].values, shears.iloc[iorder].values, redges)[:-1]
ax.plot(rcens, strue, marker="o", color="black")


ax.scatter(rarr, tshear, s = 16, label="metacal e_t", color="gray", alpha=0.5)
ax.scatter(rarr, tshear / resp, s = 16, label="metacal e_t / R", color="C1", alpha=0.5)

rcens, sraw, sraw_err = binned_signal(rarr, tshear, redges)[:-1]
ax.errorbar(rcens, sraw, sraw_err, marker="o", color="teal", lw=3, capsize=4)

rcens, sraw, sraw_err, respvals = binned_signal(rarr, tshear, redges, resp)
ax.errorbar(rcens, sraw / respvals, sraw_err / respvals, marker="o", color="magenta", lw=3, capsize=4)

ax.set_ylim(-0.3, 0.9)
ax.set_xlabel("R [arcmin]", fontsize=14)
ax.set_xlabel("R [arcmin]", fontsize=14)

ax.legend()

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

# plot the truth curve
# iorder = np.argsort(dists)
# ax.plot(dists.iloc[iorder], shears.iloc[iorder], color="black", zorder=4, lw=3, label="true input e_t")

redges = np.linspace(0, 14, 10)
rcens, strue, tmp = binned_signal(dists.iloc[iorder].values, shears.iloc[iorder].values, redges)[:-1]
ax.plot(rcens, strue, marker="o", color="black", lw=3, ls="--", label="true input signal")


ax.scatter(rarr, tshear / resp, s = 16, label="metacal $e_t / R$", color="C1", alpha=0.5)


rcens, sraw, sraw_err, respvals = binned_signal(rarr, tshear, redges, resp)
ax.errorbar(rcens, sraw / respvals, sraw_err / respvals, label="metacal $\\langle e_t \\rangle / \\langle R \\rangle$",
            marker="o", color="magenta", lw=3, capsize=4, zorder=5)

ax.set_ylim(0.001, 0.3)
ax.set_xlabel("R [arcmin]", fontsize=14)
ax.set_ylabel("$\gamma_t$", fontsize=18)
ax.set_yscale("log")
ax.legend()
# fig.savefig("metacal_field_low-isothermal_cartoon_v01.png", bbox_inches="tight")

# %%
rarr * 60.
# Out:
# array([13.4489777 , 10.17806388, 12.4899197 , 10.52312844, 14.4140714 ,
#        13.38170347, 14.59071098, 10.18233212, 14.95986753, 15.73513302,
#        16.11753818, 10.67976185, 15.38521521, 12.41069058, 11.98577671,
#        13.97042419, 16.55728736, 10.3064767 , 10.14941118, 10.11728564,
#        10.15224952, 10.75628199, 10.53736838, 15.49982256, 11.90784985,
#        12.34040712, 11.54506866, 16.50753415,  9.99285451, 12.82213509,
#        16.4374286 , 15.88117343, 11.45186068,  9.98888021, 15.47926338,
#        13.09541551, 12.22286778, 14.25145434, 14.30654232, 15.27036559,
#        11.56504264,  9.90812684, 16.37761497, 13.22028403, 15.82123834,
#        12.7216983 , 11.30049237, 15.50742458,  9.91467735, 11.66323353,
#        10.8877062 , 14.91130892, 14.96613643, 14.84448097, 10.10906068,
#        11.53774183, 14.15830055, 16.38664742, 12.71272421,  9.79850242,
#        12.86197529,  9.73039391,  9.64502407, 14.3608479 , 14.03902448,
#        12.04873641, 11.93392709, 11.81486552,  9.76837668,  9.69449068,
#         9.63478827, 14.67722366, 10.36972683, 14.96347275, 12.74946443,
#        12.08308005, 10.41050803, 15.06395078,  9.50848295,  9.52208612,
#        13.67883319,  9.45150149, 11.05949601, 10.79573692, 12.73496754,
#         9.89568484,  9.82341488, 11.02938315, 10.57389905, 11.08037152,
#         9.84356565, 13.97859381, 12.94181644, 14.17007746, 12.64128178,
#        15.45111411, 14.99573076,  9.34642673, 15.06075775, 12.45572793,
#         9.80777783, 12.3237383 , 15.95430652,  9.33975705, 10.27247595,
#        11.96206702,  9.33579481, 10.89533765,  9.32301313,  9.61697505,
#         9.63054449, 10.97852247, 15.61097571, 11.33090965, 11.49668598,
#        12.26666559, 14.25480706, 15.14499384, 14.24477535,  9.51712023,
#         9.51622986, 12.42177961, 15.26168085, 11.10777553, 15.40821429,
#         9.29536675,  9.38036058, 12.28562161, 15.37230831, 12.29520069,
#        15.93919399, 11.63461181, 15.95161912, 16.19796   , 15.64311958,
#        13.72200397, 16.08224875, 15.51256092, 11.08261682,  9.50190788,
#        12.50914017, 16.16610654, 16.22750996, 13.92538111, 14.71141277,
#        12.38205977, 15.43055709, 10.62589473, 12.9607769 ,  9.51284799,
#        10.97922521, 12.53219675,  9.86826117, 10.1243114 ,  9.52844559,
#        14.56920064, 14.61923373, 13.40284334, 12.34052922, 14.27307452,
#        14.4847181 ,  9.09695532, 10.96793386, 11.59051131, 12.40390312,
#        14.97096717,  9.44912713, 13.47289043,  9.94111449, 11.17765403,
#        16.00760237,  9.59041731,  9.51464738, 14.23642277, 11.49665815,
#        14.60663411,  9.40192569, 15.37143801, 15.28156688, 11.40783837,
#        10.45747958, 15.02115874,  9.4885581 ,  9.25162544, 14.40043636,
#        11.05095168,  9.45545244, 11.31112933, 10.8552049 , 13.94155853,
#         8.79382469,  8.75730142,  9.26253549, 12.1986974 ,  8.79062973,
#        11.25238954, 13.6265782 ,  8.85460518, 11.08457296, 11.42279254,
#        15.72559719, 11.96215917, 15.58754959,  8.70259766,  9.18071258,
#        13.11007377,  9.87341218,  8.792975  , 14.80397523, 13.25711825,
#        11.60544874,  8.68867171,  9.14966033,  9.25458467, 14.19460334,
#         9.31299531, 12.7593607 , 14.27342425, 13.10920795, 11.14445193,
#        14.16724871, 11.27877036,  8.62125526,  8.62589813, 15.05404333,
#        11.70507768, 14.880137  ,  8.6244045 , 15.77452433, 13.61773555,
#         8.57687713, 13.98941467, 11.12494779, 11.41047547,  8.49238874,
#         8.56413748,  8.66813444,  8.51405488, 15.38481623,  9.3269802 ,
#        15.08484136, 13.10004332, 15.24436736, 13.26966421, 12.4516749 ,
#         9.22151948,  8.43869556,  9.78358841, 13.0736516 , 14.32892249,
#         9.49605543,  8.47171862, 10.70994994, 10.21392069, 11.38689026,
#        12.79007263,  9.42764377,  8.64279003,  9.27592538,  8.58292435,
#         9.4392791 , 11.13843462,  8.87473492,  8.46933226,  8.96294472,
#         8.62847181, 12.19599141,  8.40794433,  8.97524734, 11.3804525 ,
#        10.67840912,  9.29087468, 15.25962079, 10.29781799, 11.66827666,
#         9.92533813, 11.85808497,  9.58377392, 11.31817315,  9.3478794 ,
#        10.486674  ,  9.14613568, 15.35833676,  8.31722531, 10.99934189,
#        10.94614593,  9.50262159,  8.37277188,  8.58681461, 12.80406533,
#        11.85282657, 15.57879878, 13.51654251,  8.70176907, 11.32129386,
#        11.13140665, 10.13002769,  8.27923274,  8.91251541, 14.95529626,
#         8.87992219,  9.67076656,  8.05559418, 10.36315572, 13.78814029,
#        10.00082958, 10.66307792,  9.81165082, 12.16237158,  9.36908492,
#        11.06875037,  8.16965929,  8.31442614, 14.46141631, 10.4038229 ,
#         8.77338118, 11.39265873,  8.69502525, 13.93537312,  9.27070483,
#        13.18872423, 10.39612563,  9.06182951,  9.82749216,  8.3170843 ,
#        14.51225766,  9.95426766,  8.60629702, 13.00459127, 11.09667675,
#         9.11245859, 12.03904768,  8.932763  , 11.73268094, 12.47434936,
#        14.86965745, 11.73522851, 12.27941201,  7.96688152, 11.22485368,
#        12.36020777, 14.62898327,  8.98282041,  7.84267975, 10.10544479,
#        11.55144236, 12.12513254,  7.82334697, 14.26787333,  8.97565731,
#        11.26059038, 13.31369489,  7.83985602, 10.98710682, 10.37573019,
#         7.74305495,  8.59735151, 12.26557941, 15.1170339 , 12.44516596,
#         9.27343537,  8.38096755,  7.80235279,  7.92249406, 10.4248873 ,
#        12.90683354,  7.64825202, 11.7533039 , 13.57787387, 14.02032947,
#        12.27145533, 11.59648283,  7.8871382 ,  8.93465721, 14.10036273,
#         8.99748649, 11.63848967,  7.64859228, 11.7581909 , 12.89106106,
#        12.00212197,  8.85251114,  8.8200954 ,  8.26115574, 11.90006158,
#        13.97925569, 10.98905811,  8.13216663, 13.05455753,  7.37868244,
#         7.94183234,  8.48440943, 13.22247877,  8.13628553,  9.91138337,
#         8.88452838,  9.34807565, 12.45605042,  9.98516816,  7.41257033,
#        12.5686258 , 14.58666384,  7.8304312 , 14.25100444,  8.76861071,
#        11.05960255, 14.34917458,  8.65779146, 13.16709828,  8.90662737,
#        13.00695448,  8.76728253,  7.37175034,  7.75201275,  9.13224947,
#         9.61346175, 11.45103282,  9.47168622, 11.85499638,  7.40244281,
#        14.9560376 , 13.82766957,  9.11853423, 10.99206063,  9.51282722,
#        12.90286105,  9.41971819, 13.40943218,  9.95901259,  8.68586387,
#         9.36093474, 12.2162322 , 14.20189039,  9.58215526,  7.45000085,
#         7.46982864,  8.08036714, 14.36755088,  9.93691307, 12.72954613,
#         8.98823139,  9.89608176,  7.53909565,  9.16307826, 10.66292961,
#         9.54466642, 14.97981667,  9.70034302, 13.9805071 ,  7.70112852,
#         7.85723617,  8.18041312, 10.34926586,  9.43556887, 12.24997083,
#         8.42975092,  9.90537849,  7.83507563,  7.95489518,  7.11107193,
#        15.09597499,  7.27992466,  9.32221681,  7.86244043, 11.73419063,
#        12.99757003, 14.97957271,  8.3025137 ,  8.64580804, 10.43416267,
#         7.98899619,  9.8690368 , 14.07219143,  8.02586128,  7.87874128,
#         8.00101364,  9.32008426, 10.69295429, 10.04749684, 11.14019178,
#        14.20397243,  8.2377949 , 13.39914964,  8.55184707,  7.39394563,
#        11.05863996,  7.22282522, 11.34267131, 14.19117117, 11.32087059,
#         7.05011899,  7.49516634,  7.13030185, 10.75664979,  7.0678971 ,
#        13.75063802,  7.80395514, 14.46670213, 10.50352668, 10.40740436,
#        10.35845416,  7.83486353, 12.99960855,  8.1519203 , 12.52981232,
#        11.21756636, 14.10811296,  8.71929095,  6.98546644,  6.99843054,
#        13.31839281,  7.76896171,  8.69278432, 11.79374619,  7.36106135,
#         8.53126522, 11.6334829 ,  7.98889226,  7.14348686, 10.2604995 ,
#        13.23984453,  6.79352493,  6.98840276,  9.85890006,  9.60170987,
#        12.70611889, 10.17885789,  7.69349283, 11.57953632, 12.93622765,
#        10.1955498 , 10.23830412, 11.36278912, 13.00115105,  7.36402177,
#         7.42010791,  6.92278053,  7.43885473, 10.0441986 ,  7.5389405 ,
#        10.93960465, 14.87250912,  8.10669846,  9.65920188,  6.58454486,
#        13.79587626, 10.13381837, 11.35011775,  9.10997433,  9.58797584,
#         8.71508036,  6.86012821,  7.43053672,  8.74026705,  6.74498135,
#         6.49255348,  6.70247822, 12.42536157, 11.90141923,  7.56951996,
#         7.80488767,  7.94732786, 10.06806776, 11.5347511 , 14.66802401,
#         9.12040906, 13.30327851,  7.89599569, 10.07814084, 14.37632444,
#        12.48949129, 11.03271872, 11.42439356,  7.29580926,  9.62266314,
#         7.83739993,  7.77731898,  7.89578201,  7.73403565, 12.76409783,
#        14.65954856,  6.27405183,  9.27738184, 14.44851533,  8.31174396,
#         9.18927593,  7.51503693, 10.9107143 , 11.18707433,  7.23287086,
#         9.38765508,  8.95251338,  6.57679364,  7.50393673,  7.03109255,
#         7.70512289, 12.35014757,  6.5938539 ,  9.61231324, 10.29890641,
#         9.37963856,  6.57070295,  8.5018399 ,  7.66171803,  8.28884201,
#         6.13124152,  6.2544257 ,  6.96115844, 14.55603116,  6.48455566,
#         6.70421712,  6.44726026,  6.94143135,  9.64207823,  7.58846571,
#         9.31008682, 10.38531403, 14.46356564, 12.03278931,  6.62600999,
#         7.59396453, 10.29892242, 10.54393844,  9.07429886,  8.55356305,
#        13.16478676,  7.78938648, 13.48452667,  6.83716997,  6.08306721,
#         8.30744914,  6.72840106,  5.91200028,  6.77511205, 11.92106012,
#         6.10737461,  6.0738151 ,  6.37775128,  5.87613915,  7.2560692 ,
#         9.05980819,  9.61351654, 13.66540702,  6.51420037,  9.3264017 ,
#        11.37989982,  6.04279906,  5.98784523,  6.75131085,  9.56206805,
#        12.51174539,  6.38285067, 11.78538325,  6.24514602,  6.24632426,
#         9.99190659, 12.15186618,  6.08031787, 13.05203626,  5.79601405,
#         6.62422641, 12.03691896, 14.49126921, 12.25289632,  8.33118358,
#         5.93400922,  5.7029575 ,  5.75370386, 12.9361411 , 10.28705694,
#         6.23906522, 13.00605158,  6.63491755,  9.7533825 ,  5.76034467,
#         8.76069332,  5.68791602,  9.32473346, 10.24456932, 13.31057472,
#         5.5651184 ,  7.83375905, 11.8932023 ,  5.917375  , 12.42482723,
#         5.82506189,  9.96269639,  6.33363481, 12.85293129,  5.73572871,
#        10.11803575, 13.98062325, 14.16902126,  6.42971198, 12.11356686,
#        14.1445817 ,  6.04982033, 10.92025549, 13.0539443 , 10.22795026,
#         7.08411289, 12.56603961,  9.43390862,  7.89356165, 12.22317176,
#        12.33366398,  9.86705276, 12.33044277, 13.65236793, 10.70270419,
#         5.37992443, 10.58029011,  8.59533386,  5.2823208 , 12.5877546 ,
#         8.73732847,  8.04135149,  5.88847192,  8.28550547,  8.88725529,
#        10.945692  , 12.36408905, 10.73799909,  9.83248684, 13.87253228,
#         9.22109474, 11.90638244, 10.19840299,  9.35943527,  7.13148446,
#         9.40749609, 12.12068164,  5.15046868,  6.37090585,  6.75591731,
#         8.63202638,  5.68617395,  5.69488584,  6.06393607,  5.12907381,
#         6.04022757, 10.6954168 , 13.73070172,  5.57161686, 14.13421662,
#        11.20473103, 11.09441087,  6.58147823,  5.45730481, 12.18661696,
#        12.47933849,  9.13912707, 13.60678346, 12.1458033 , 14.03055278,
#         9.64165873,  5.11888003,  8.69433884,  6.55150537,  6.00894652,
#        11.63946832,  6.54891307,  6.53127233, 13.26504386,  6.73195766,
#         5.11056961,  6.27440629, 11.6687472 ,  7.76745594,  7.58111988,
#        12.86639183,  8.23793696, 13.23593585, 10.29462287,  7.19859234,
#         4.92261026, 12.31553596,  5.76864185,  8.97588963, 12.9887138 ,
#         4.96332449, 11.47490558,  8.77850314,  5.40987754, 10.70816377,
#         8.14051664,  7.29514621, 11.8604915 ,  9.85769066,  8.22386538,
#         7.36955858,  4.87177245, 10.57516881,  9.2749129 ,  5.79058703,
#        10.96425039,  9.02696984, 10.76131139,  8.60591695,  5.90955618,
#         7.48822572,  5.91276697,  5.80830745, 13.89952216, 11.66319308,
#         7.82725745, 11.79331191,  4.96816479,  4.70490502, 10.59182818,
#        13.50712001,  7.72888352, 10.01827073,  4.64767023,  6.0947101 ,
#         5.33838789,  5.04094848, 12.20173724,  5.25116014, 13.63027858,
#         5.04094784,  4.87457656, 12.73357366, 13.12128589, 10.96615031,
#         9.31788884,  5.19153326,  6.68107139, 13.97663985,  4.88485418,
#         4.71361348, 12.81605384,  8.10327575,  7.84295056,  8.48851664,
#         9.90133395, 10.27432465, 11.9197671 , 11.95327774, 13.21380335,
#         7.33141099,  9.49517991, 12.12372905,  9.14895918,  9.66264743,
#         8.50958144,  4.43302409,  5.68137902,  4.34859982,  5.4885291 ,
#        12.9628583 , 12.07789726,  6.19974798,  4.61168602, 11.85464582,
#        13.82052102,  5.41970617, 13.26059315,  8.9305734 ,  9.9495813 ,
#        11.83738075, 13.90232402, 10.76414901,  6.29017231, 12.1380236 ,
#         9.4097309 ,  5.33506945,  5.52870344, 12.99317345,  4.17441573,
#         7.63025728, 13.27782908,  4.27178796,  4.10608345,  4.09938002,
#        12.3989738 ,  8.63484092, 12.56460362, 12.60324912,  7.38051352,
#        11.38338964,  8.84218661, 10.83798524,  7.55141525, 12.27879083,
#        12.48838779,  8.92552484,  9.26758851,  6.07640427,  7.19555061,
#         3.99298426, 13.22552422,  3.98751342,  6.78067406,  3.92799905,
#         3.90890875,  6.95954458,  7.7444918 , 13.73535299,  4.87513475,
#         6.22707267,  9.95536549,  4.43042796,  4.75178319,  7.78519975,
#        10.23374089,  4.19171268,  3.97083687,  7.08853051,  3.87554781,
#        13.64941939,  4.08746971,  3.92573391, 10.09458178, 13.31562022,
#        12.08590087,  3.78563907,  3.81348876,  3.91584313, 12.8289767 ,
#         3.9416209 ,  8.94608998,  5.12357137, 13.74118988, 12.35212832,
#        13.16817662, 10.00214665,  4.21049875, 13.49581808, 11.96127382,
#         4.28537275,  6.01139552,  9.35086226,  4.96522067,  5.66512689,
#         6.39283248,  7.91938665,  7.81053459,  6.97825379, 13.17077581,
#        12.81121668,  6.0981543 ,  7.16072534,  5.85254673, 11.58705831,
#        10.26110398, 12.8837593 , 13.66120908,  3.57265719,  5.18627163,
#         3.78219648, 10.86509641,  3.53596111, 10.00551403,  5.48306327,
#        10.02196008,  5.78486369,  7.50599276,  3.52097984,  3.57136561,
#        13.01415135,  4.98780549,  5.07973753, 10.62648709,  4.33475879,
#         8.89995413, 12.42117411,  6.30254389,  3.96351464,  4.60415821,
#         9.18913871,  8.85910813, 12.43110465,  5.47968427, 13.24407483,
#         4.11717633, 13.18824467,  4.20207175,  9.17544505, 12.34467278,
#         4.5454102 ,  7.14985477,  7.20537628, 13.04267785,  5.08946239,
#        13.44077407,  5.66482808,  3.89626777,  3.40585751,  4.50109154,
#        13.18366665, 11.28021898, 12.16901335, 11.55841828,  5.59664703,
#         9.61679831,  3.44219413,  4.71203796,  4.37883936,  8.6285791 ])
