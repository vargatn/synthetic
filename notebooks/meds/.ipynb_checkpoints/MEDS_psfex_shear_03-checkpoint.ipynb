# %%
import numpy as np
import pandas as pd

import sklearn.neighbors as neighbors

from importlib import reload
import copy
import synthetic.render.generator as gen

import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

import multiprocessing as mp

import sys
import os
import math
import logging
import time
import galsim
import fitsio as fio

import ngmix

import synthetic.render.render as render
import synthetic.render.icl as icl
import synthetic.render.frame as frame

import images
import meds
import subprocess

# %%
catalogs = []
catalog_tag = '/e/ocean1/users/vargatn/DES/SIM_DATA/SKY_MODEL_EPSILON/res_clust_v2_z0l0/epsilon_clust_v8-z0l0_15000_{:03d}.fits'
for i in np.arange(1):
    fname = catalog_tag.format(i)
    data = fio.read(fname)
    catalog_cluster = data[data['LOC'] == 1]
    catalog_field = data[data['LOC'] == 0]
    catalog = np.hstack((catalog_cluster, catalog_field))
    catalog['G1'] = 0.3
    catalog['G2'] = -0.2
    catalogs.append(catalog)

# %%
x = np.linspace(201, 4700, 20) + 2500
y = np.linspace(201, 4700, 20) + 2500
xx, yy = np.meshgrid(x, y)
xx = xx.flatten()
yy = yy.flatten()

# %%
star_catalog = copy.deepcopy(catalog[:400])
star_catalog[:] = 0
mag = 30  - 2.5 * np.log10(5e4)

# %%
star_catalog["X"] = xx 
star_catalog["Y"] = yy
star_catalog["FLUX_G"][:] = 5e4
star_catalog["FLUX_R"][:] = 5e4
star_catalog["FLUX_I"][:] = 5e4
star_catalog["FLUX_Z"][:] = 5e4
star_catalog["TSIZE"][:] = 1e-3
star_catalog["MAG_G"][:] = mag
star_catalog["MAG_R"][:] = mag
star_catalog["MAG_I"][:] = mag
star_catalog["MAG_Z"][:] = mag
star_catalog["FRACDEV"][:] = mag

# %%
rd = render.DrawField(5000., star_catalog)

# %%
name = 'star_canvas'
print(name)
fr = frame.Frame(star_catalog, name=name, noise_std=4)
fr.render()
fr.extract()
# Out:
# star_canvas
# starting xshear calculations in 100 processes
# galsim.BoundsI(1140,1157,4455,4472)
# galsim.BoundsI(1376,1393,4455,4472)
# galsim.BoundsI(1613,1630,4455,4472)
# galsim.BoundsI(1850,1867,4455,4472)
# galsim.BoundsI(193,210,4455,4472)galsim.BoundsI(3981,3998,4455,4472)
#
# galsim.BoundsI(429,446,4455,4472)
# galsim.BoundsI(4218,4235,4455,4472)
# galsim.BoundsI(666,683,4455,4472)
# galsim.BoundsI(4455,4472,4455,4472)
# galsim.BoundsI(903,920,4455,4472)
# galsim.BoundsI(4692,4709,4455,4472)
# galsim.BoundsI(193,210,3981,3998)
# galsim.BoundsI(193,210,3034,3051)
# galsim.BoundsI(429,446,3981,3998)
# galsim.BoundsI(3981,3998,3271,3288)
# galsim.BoundsI(429,446,3034,3051)
# galsim.BoundsI(2087,2104,3981,3998)galsim.BoundsI(666,683,3981,3998)
# galsim.BoundsI(4218,4235,3271,3288)galsim.BoundsI(666,683,3034,3051)
#
#
# galsim.BoundsI(2324,2341,3981,3998)galsim.BoundsI(903,920,3981,3998)galsim.BoundsI(903,920,3034,3051)galsim.BoundsI(193,210,3271,3288)galsim.BoundsI(4455,4472,3271,3288)
# galsim.BoundsI(1613,1630,1140,1157)
# galsim.BoundsI(2324,2341,666,683)galsim.BoundsI(1850,1867,903,920)galsim.BoundsI(3744,3761,903,920)galsim.BoundsI(903,920,903,920)
#
#
#
# galsim.BoundsI(4455,4472,2560,2577)
# galsim.BoundsI(1850,1867,1140,1157)
#
# galsim.BoundsI(3981,3998,903,920)galsim.BoundsI(4692,4709,2560,2577)
#
# galsim.BoundsI(3034,3051,1850,1867)galsim.BoundsI(2560,2577,666,683)
#
# galsim.BoundsI(4218,4235,903,920)
# galsim.BoundsI(1140,1157,1850,1867)galsim.BoundsI(2797,2814,666,683)
# galsim.BoundsI(4455,4472,903,920)galsim.BoundsI(3271,3288,1850,1867)galsim.BoundsI(2087,2104,1613,1630)
#
#
# galsim.BoundsI(1376,1393,1850,1867)
# galsim.BoundsI(4692,4709,903,920)galsim.BoundsI(3034,3051,1140,1157)
#
# galsim.BoundsI(3508,3525,1850,1867)galsim.BoundsI(1613,1630,1850,1867)
#
# galsim.BoundsI(193,210,2324,2341)galsim.BoundsI(2324,2341,1613,1630)
#
# galsim.BoundsI(3271,3288,1140,1157)galsim.BoundsI(3744,3761,1850,1867)
# galsim.BoundsI(1850,1867,1850,1867)
#
# galsim.BoundsI(429,446,2324,2341)galsim.BoundsI(2560,2577,1613,1630)
#
# galsim.BoundsI(3508,3525,1140,1157)
# galsim.BoundsI(666,683,2324,2341)
# galsim.BoundsI(2797,2814,1613,1630)
# galsim.BoundsI(903,920,2324,2341)
# galsim.BoundsI(3744,3761,1140,1157)
# galsim.BoundsI(2087,2104,903,920)
# galsim.BoundsI(2324,2341,903,920)
# galsim.BoundsI(2560,2577,903,920)
# galsim.BoundsI(3981,3998,1376,1393)
# galsim.BoundsI(2797,2814,903,920)
# galsim.BoundsI(2087,2104,1376,1393)
# galsim.BoundsI(4218,4235,1376,1393)
# galsim.BoundsI(2324,2341,1376,1393)
# galsim.BoundsI(2087,2104,193,210)galsim.BoundsI(2560,2577,1376,1393)galsim.BoundsI(4455,4472,1376,1393)
#
#
# galsim.BoundsI(193,210,1850,1867)
# galsim.BoundsI(4692,4709,1376,1393)
# galsim.BoundsI(2797,2814,1376,1393)
# galsim.BoundsI(2324,2341,193,210)galsim.BoundsI(429,446,1850,1867)
#
# galsim.BoundsI(666,683,1850,1867)
# galsim.BoundsI(2560,2577,193,210)
# galsim.BoundsI(903,920,1850,1867)
# galsim.BoundsI(2797,2814,193,210)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_157497/2834335382.py in <module>
#       2 print(name)
#       3 fr = frame.Frame(star_catalog, name=name, noise_std=4)
# ----> 4 fr.render()
#       5 fr.extract()
#
# ~/DES/SYNTHETIC/synthetic/synthetic/render/frame.py in render(self, nprocess)
#      33         self.canvas += self.noise
#      34
# ---> 35         self.write()
#      36
#      37     def write(self):
#
# ~/DES/SYNTHETIC/synthetic/synthetic/render/frame.py in write(self)
#      37     def write(self):
#      38         self.file_name = self.name + ".fits"
# ---> 39         self.canvas.write(self.file_name, clobber=True)
#      40         #fio.write(self.file_name, self.canvas.array, clobber=True)
#      41         self.file_name_psf = self.name + "_epsf.fits"
#
# ~/anaconda3/envs/galsim/lib/python3.7/site-packages/galsim/fits.py in write(image, file_name, dir, hdu_list, clobber, compression)
#     454
#     455     if file_name:
# --> 456         _write_file(file_name, dir, hdu_list, clobber, file_compress, pyfits_compress)
#     457
#     458
#
# ~/anaconda3/envs/galsim/lib/python3.7/site-packages/galsim/fits.py in __call__(self, file, dir, hdu_list, clobber, file_compress, pyfits_compress)
#     274
#     275         if not file_compress:
# --> 276             hdu_list.writeto(file)
#     277         elif file_compress == 'gzip':
#     278             while self.gz_index < len(self.gz_methods):
#
# ~/anaconda3/envs/galsim/lib/python3.7/site-packages/astropy/utils/decorators.py in wrapper(*args, **kwargs)
#     534                     warnings.warn(message, warning_type, stacklevel=2)
#     535
# --> 536             return function(*args, **kwargs)
#     537
#     538         return wrapper
#
# ~/anaconda3/envs/galsim/lib/python3.7/site-packages/astropy/io/fits/hdu/hdulist.py in writeto(self, fileobj, output_verify, overwrite, checksum)
#     951             for hdu in self:
#     952                 hdu._prewriteto(checksum=checksum)
# --> 953                 hdu._writeto(hdulist._file)
#     954                 hdu._postwriteto()
#     955         hdulist.close(output_verify=output_verify, closed=closed)
#
# ~/anaconda3/envs/galsim/lib/python3.7/site-packages/astropy/io/fits/hdu/base.py in _writeto(self, fileobj, inplace, copy)
#     684
#     685         with _free_space_check(self, dirname):
# --> 686             self._writeto_internal(fileobj, inplace, copy)
#     687
#     688     def _writeto_internal(self, fileobj, inplace, copy):
#
# ~/anaconda3/envs/galsim/lib/python3.7/site-packages/astropy/io/fits/hdu/base.py in _writeto_internal(self, fileobj, inplace, copy)
#     690         if not inplace or self._new:
#     691             header_offset, _ = self._writeheader(fileobj)
# --> 692             data_offset, data_size = self._writedata(fileobj)
#     693
#     694             # Set the various data location attributes on newly-written HDUs
#
# ~/anaconda3/envs/galsim/lib/python3.7/site-packages/astropy/io/fits/hdu/base.py in _writedata(self, fileobj)
#     622         if self._data_loaded or self._data_needs_rescale:
#     623             if self.data is not None:
# --> 624                 size += self._writedata_internal(fileobj)
#     625             # pad the FITS data block
#     626             if size > 0:
#
# ~/anaconda3/envs/galsim/lib/python3.7/site-packages/astropy/io/fits/hdu/image.py in _writedata_internal(self, fileobj)
#     648                     output.byteswap(True)
#     649                     try:
# --> 650                         fileobj.writearray(output)
#     651                     finally:
#     652                         output.byteswap(True)
#
# ~/anaconda3/envs/galsim/lib/python3.7/site-packages/astropy/io/fits/file.py in writearray(self, array)
#     358             return
#     359         if hasattr(self._file, 'write'):
# --> 360             _array_to_file(array, self._file)
#     361
#     362     def flush(self):
#
# ~/anaconda3/envs/galsim/lib/python3.7/site-packages/astropy/io/fits/util.py in _array_to_file(arr, outfile)
#     636     else:
#     637         # Just pass the whole array to the write routine
# --> 638         return write(arr, outfile)
#     639
#     640     # Write one chunk at a time for systems whose fwrite chokes on large
#
# ~/anaconda3/envs/galsim/lib/python3.7/site-packages/astropy/io/fits/util.py in <lambda>(a, f)
#     614
#     615     if isfile(outfile) and not isinstance(outfile, io.BufferedIOBase):
# --> 616         write = lambda a, f: a.tofile(f)
#     617     else:
#     618         write = _array_to_file_like
#
# KeyboardInterrupt:

# %%
! sex canvas_000.fits -c config.sex -CATALOG_TYPE FITS_LDAC -CATALOG_NAME canvas_000_cat.ldac -CHECKIMAGE_NAME canvas_000_seg.fits
# Out:
# >
# ----- SExtractor 2.25.0 started on 2022-10-10 at 13:32:55 with 1 thread
#
# > Setting catalog parameters
# > Reading detection filter
# > Initializing Neural Network
# > Reading Neural Network Weights
# > Initializing check-image(s)
# > Initializing catalog
# > Looking for canvas_000.fits
# ----- Measuring from: canvas_000.fits
#       "Unnamed" / no ext. header / 5000x5000 / 32 bits (floats)
# Detection+Measurement image: > Setting up background maps
# > Setting up background map at line:   64
# > Setting up background map at line:  128
# > Setting up background map at line:  192
# > Setting up background map at line:  256
# > Setting up background map at line:  320
# > Setting up background map at line:  384
# > Setting up background map at line:  448
# > Setting up background map at line:  512
# > Setting up background map at line:  576
# > Setting up background map at line:  640
# > Setting up background map at line:  704
# > Setting up background map at line:  768
# > Setting up background map at line:  832
# > Setting up background map at line:  896
# > Setting up background map at line:  960
# > Setting up background map at line: 1024
# > Setting up background map at line: 1088
# > Setting up background map at line: 1152
# > Setting up background map at line: 1216
# > Setting up background map at line: 1280
# > Setting up background map at line: 1344
# > Setting up background map at line: 1408
# > Setting up background map at line: 1472
# > Setting up background map at line: 1536
# > Setting up background map at line: 1600
# > Setting up background map at line: 1664
# > Setting up background map at line: 1728
# > Setting up background map at line: 1792
# > Setting up background map at line: 1856
# > Setting up background map at line: 1920
# > Setting up background map at line: 1984
# > Setting up background map at line: 2048
# > Setting up background map at line: 2112
# > Setting up background map at line: 2176
# > Setting up background map at line: 2240
# > Setting up background map at line: 2304
# > Setting up background map at line: 2368
# > Setting up background map at line: 2432
# > Setting up background map at line: 2496
# > Setting up background map at line: 2560
# > Setting up background map at line: 2624
# > Setting up background map at line: 2688
# > Setting up background map at line: 2752
# > Setting up background map at line: 2816
# > Setting up background map at line: 2880
# > Setting up background map at line: 2944
# > Setting up background map at line: 3008
# > Setting up background map at line: 3072
# > Setting up background map at line: 3136
# > Setting up background map at line: 3200
# > Setting up background map at line: 3264
# > Setting up background map at line: 3328
# > Setting up background map at line: 3392
# > Setting up background map at line: 3456
# > Setting up background map at line: 3520
# > Setting up background map at line: 3584
# > Setting up background map at line: 3648
# > Setting up background map at line: 3712
# > Setting up background map at line: 3776
# > Setting up background map at line: 3840
# > Setting up background map at line: 3904
# > Setting up background map at line: 3968
# > Setting up background map at line: 4032
# > Setting up background map at line: 4096
# > Setting up background map at line: 4160
# > Setting up background map at line: 4224
# > Setting up background map at line: 4288
# > Setting up background map at line: 4352
# > Setting up background map at line: 4416
# > Setting up background map at line: 4480
# > Setting up background map at line: 4544
# > Setting up background map at line: 4608
# > Setting up background map at line: 4672
# > Setting up background map at line: 4736
# > Setting up background map at line: 4800
# > Setting up background map at line: 4864
# > Setting up background map at line: 4928
# > Setting up background map at line: 4992
# > Filtering background map(s)
# > Computing background d-map
# > Computing background-noise d-map
# (M+D) Background: 0.0695561  RMS: 3.99903    / Threshold: 5.99854
# > Scanning image
# > Line:   25  Objects:        0 detected /        0 sextracted
# > Line:   50  Objects:        0 detected /        0 sextracted
# > Line:   75  Objects:        0 detected /        0 sextracted
# > Line:  100  Objects:        0 detected /        0 sextracted
# > Line:  125  Objects:        0 detected /        0 sextracted
# > Line:  150  Objects:        0 detected /        0 sextracted
# > Line:  175  Objects:        0 detected /        0 sextracted
# > Line:  200  Objects:        0 detected /        0 sextracted
# > Line:  225  Objects:        1 detected /        0 sextracted
# > Line:  250  Objects:       11 detected /        0 sextracted
# > Line:  275  Objects:       24 detected /        0 sextracted
# > Line:  300  Objects:       39 detected /        0 sextracted
# > Line:  325  Objects:       56 detected /        0 sextracted
# > Line:  350  Objects:       77 detected /        0 sextracted
# > Line:  375  Objects:       96 detected /        0 sextracted
# > Line:  400  Objects:      128 detected /        0 sextracted
# > Line:  425  Objects:      157 detected /        0 sextracted
# > Line:  450  Objects:      186 detected /        0 sextracted
# > Line:  475  Objects:      228 detected /        0 sextracted
# > Line:  500  Objects:      268 detected /        0 sextracted
# > Line:  525  Objects:      304 detected /        0 sextracted
# > Line:  550  Objects:      339 detected /        0 sextracted
# > Line:  575  Objects:      365 detected /        0 sextracted
# > Line:  600  Objects:      403 detected /        0 sextracted
# > Line:  625  Objects:      436 detected /        0 sextracted
# > Line:  650  Objects:      467 detected /        0 sextracted
# > Line:  675  Objects:      499 detected /        0 sextracted
# > Line:  700  Objects:      541 detected /        0 sextracted
# > Line:  725  Objects:      584 detected /        0 sextracted
# > Line:  750  Objects:      635 detected /        0 sextracted
# > Line:  775  Objects:      680 detected /        0 sextracted
# > Line:  800  Objects:      717 detected /        0 sextracted
# > Line:  825  Objects:      754 detected /        0 sextracted
# > Line:  850  Objects:      798 detected /        0 sextracted
# > Line:  875  Objects:      841 detected /        0 sextracted
# > Line:  900  Objects:      876 detected /        0 sextracted
# > Line:  925  Objects:      925 detected /        0 sextracted
# > Line:  950  Objects:      969 detected /        0 sextracted
# > Line:  975  Objects:     1014 detected /        0 sextracted
# > Line: 1000  Objects:     1057 detected /        0 sextracted
# > Line: 1025  Objects:     1122 detected /        0 sextracted
# > Line: 1050  Objects:     1172 detected /        0 sextracted
# > Line: 1075  Objects:     1227 detected /        0 sextracted
# > Line: 1100  Objects:     1281 detected /        0 sextracted
# > Line: 1125  Objects:     1344 detected /        0 sextracted
# > Line: 1150  Objects:     1405 detected /        0 sextracted
# > Line: 1175  Objects:     1452 detected /        0 sextracted
# > Line: 1200  Objects:     1500 detected /        0 sextracted
# > Line: 1221  Objects:     1544 detected /        0 sextracted
# > Line: 1225  Objects:     1554 detected /        1 sextracted
# > Line: 4675  Objects:     9629 detected /     7640 sextracted
# > Line: 4700  Objects:     9653 detected /     7690 sextracted
# > Line: 4725  Objects:     9666 detected /     7736 sextracted
# > Line: 4750  Objects:     9680 detected /     7775 sextracted
# > Line: 4775  Objects:     9685 detected /     7841 sextracted
# > Line: 4800  Objects:     9687 detected /     7886 sextracted
# > Line: 4825  Objects:     9687 detected /     7942 sextracted
# > Line: 4850  Objects:     9687 detected /     7997 sextracted
# > Line: 4852  Objects:     9687 detected /     8000 sextracted
# > Line: 4875  Objects:     9687 detected /     8039 sextracted
# > Line: 4900  Objects:     9687 detected /     8090 sextracted
# > Line: 4925  Objects:     9687 detected /     8144 sextracted
# > Line: 4950  Objects:     9687 detected /     8198 sextracted
# > Line: 4975  Objects:     9687 detected /     8242 sextracted
# > Line: 5000  Objects:     9687 detected /     8286 sextracted
# > Line: 5000  Objects:     9687 detected /     8400 sextracted
# > Line: 5000  Objects:     9687 detected /     8800 sextracted
# > Line: 5000  Objects:     9687 detected /     9200 sextracted
#       Objects: detected 9687     / sextracted 9347
#
# > Closing files
# >
# > All done (in 4.4 s: 1142.7 lines/s , 2136.2 detections/s)

# %%
# !psfex canvas_000_cat.ldac -c psfex.config
# Out:
# > WARNING: This executable has been compiled using a version of the ATLAS library without support for multithreading. Performance will be degraded.
#
# .
# ----- PSFEx 3.21.1 started on 2022-10-10 at 14:55:39 with 160 threads
#
# .
# ----- 1 input catalogues:
# canvas_000_cat.ldac :  "no ident        "    1 extension    9347 detections
#
# Initializing contexts....
# Computing optimum PSF sampling steps....
# Reading data from canvas_000_cat....
#
# > WARNING: No source with appropriate FWHM found!!
#
# Computing final PSF model for canvas_000_cat....
# Computing diagnostics for canvas_000_cat....
#
# > WARNING: No source with appropriate FWHM found!!
#
# canvas_000_cat               0/0       0.75   0.00   0.00  0.00  1.00  1.00
# Saving CHECK-image #1....
# Saving CHECK-image #2....
# Saving CHECK-image #3....
# Saving CHECK-image #4....
# Saving CHECK-image #5....
# Saving PSF model and metadata for canvas_000_cat....
# Writing XML file....
# .

# %%
ff = fio.FITS('canvas_000_cat.ldac')

# %%
51 / 41
# Out:
# 1.2439024390243902

# %%
imcat_ldac_name=imagefile.replace('.fits','_cat.ldac')

        bkgname=imagefile.replace('.fits','.sub.fits')
        bkg_arg = '-CHECKIMAGE_NAME ' + bkgname

        cmd = ' '.join(['sex',imagefile,'-WEIGHT_IMAGE',weightfile,'-c',sextractor_config_file,'-CATALOG_NAME ',
                            imcat_ldac_name, bkg_arg, sextractor_param_arg,sextractor_nnw_arg,sextractor_filter_arg])

# %%
plt.hist(fr.scat['VIGNET'][0].flatten())
# Out:
# (array([ 68.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0., 893.]),
#  array([-1.000000e+30, -9.000000e+29, -8.000000e+29, -7.000000e+29,
#         -6.000000e+29, -5.000000e+29, -4.000000e+29, -3.000000e+29,
#         -2.000000e+29, -1.000000e+29,  8.145627e+01], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
plt.imshow(fr.scat['VIGNET'][8])
