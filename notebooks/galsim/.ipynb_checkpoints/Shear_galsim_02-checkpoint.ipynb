# %%
import numpy as np
import pandas as pd

from importlib import reload

import synthetic.render.generator as gen

import matplotlib.pyplot as plt
# %matplotlib inline

import multiprocessing as mp

import sys
import os
import math
import logging
import time
import galsim
import fitsio as fio

import ngmix

import synthetic.render.render as render
import synthetic.render.icl as icl
import images

# %%
catalog_path = '/e/ocean1/users/vargatn/DES/SIM_DATA/SKY_MODEL_EPSILON/res_clust_v2_z0l0/epsilon_clust_v8-z0l0_15000_000.fits'
data = fio.read(catalog_path)
catalog_cluster = data[data['LOC'] == 1]
catalog_field = data[data['LOC'] == 0]

# %%
catalog = np.hstack((catalog_cluster, catalog_field))

# %%
catalog["G1"] = 0.05
catalog["G1"] = -0.02

# %%
df = render.DrawField(5000, catalog, band="i")

# %%
df.prepare()
df.make_infodicts()
df.multi_render(100)
df.collate_stamps()
# Out:
# starting xshear calculations in 100 processes
# Process ForkPoolWorker-217:
# Process ForkPoolWorker-285:
# Process ForkPoolWorker-296:
# Process ForkPoolWorker-229:
# Process ForkPoolWorker-288:
# Process ForkPoolWorker-283:
# Process ForkPoolWorker-289:
# Process ForkPoolWorker-278:
# Process ForkPoolWorker-221:
# Process ForkPoolWorker-281:
# Process ForkPoolWorker-259:
# Process ForkPoolWorker-290:
# Process ForkPoolWorker-294:
# Process ForkPoolWorker-292:
# Process ForkPoolWorker-291:
# Process ForkPoolWorker-230:
# Process ForkPoolWorker-223:
# Process ForkPoolWorker-224:
# Process ForkPoolWorker-215:
# Process ForkPoolWorker-218:
# Process ForkPoolWorker-205:
# Process ForkPoolWorker-201:
# Process ForkPoolWorker-226:
# Process ForkPoolWorker-207:
# Process ForkPoolWorker-219:
# Process ForkPoolWorker-216:
# Process ForkPoolWorker-227:
# Process ForkPoolWorker-204:
# Process ForkPoolWorker-210:
# Process ForkPoolWorker-209:
# Process ForkPoolWorker-211:
# Process ForkPoolWorker-231:
# Process ForkPoolWorker-258:
# Process ForkPoolWorker-208:
# Process ForkPoolWorker-203:
# Process ForkPoolWorker-254:
# Process ForkPoolWorker-287:
# Process ForkPoolWorker-220:
# Process ForkPoolWorker-261:
# Process ForkPoolWorker-243:
# Process ForkPoolWorker-253:
# Process ForkPoolWorker-213:
# Process ForkPoolWorker-222:
# Process ForkPoolWorker-225:
# Process ForkPoolWorker-228:
# Process ForkPoolWorker-245:
# Process ForkPoolWorker-284:
# Process ForkPoolWorker-214:
# Process ForkPoolWorker-295:
# Process ForkPoolWorker-212:
# Process ForkPoolWorker-206:
# Process ForkPoolWorker-265:
# Process ForkPoolWorker-277:
# Process ForkPoolWorker-255:
# Process ForkPoolWorker-267:
# Process ForkPoolWorker-293:
# Process ForkPoolWorker-268:
# Process ForkPoolWorker-280:
# Process ForkPoolWorker-298:
# Process ForkPoolWorker-260:
# Process ForkPoolWorker-244:
# Process ForkPoolWorker-252:
# Process ForkPoolWorker-263:
# Process ForkPoolWorker-237:
# Process ForkPoolWorker-264:
# Process ForkPoolWorker-270:
# Process ForkPoolWorker-238:
# Process ForkPoolWorker-286:
# Caught KeyboardInterrupt, terminating workers
# Process ForkPoolWorker-271:
# Process ForkPoolWorker-242:
# Process ForkPoolWorker-300:
# Process ForkPoolWorker-282:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/DES/SYNTHETIC/synthetic/synthetic/render/render.py in multi_render(self, nprocess)
#     184             pp = pool.map_async(self.call_chunks, fparchunks)
# --> 185             res = pp.get(172800)  # apparently this counters a bug in the exception passing in python.subprocess...
#     186
#
# ~/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py in get(self, timeout)
#     650     def get(self, timeout=None):
# --> 651         self.wait(timeout)
#     652         if not self.ready():
#
# ~/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py in wait(self, timeout)
#     647     def wait(self, timeout=None):
# --> 648         self._event.wait(timeout)
#     649
#
# ~/anaconda3/envs/galsim/lib/python3.7/threading.py in wait(self, timeout)
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#
# ~/anaconda3/envs/galsim/lib/python3.7/threading.py in wait(self, timeout)
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# EOFError                                  Traceback (most recent call last)
# <ipython-input-112-a050493a65b1> in <module>
#       1 df.prepare()
#       2 df.make_infodicts()
# ----> 3 df.multi_render(100)
#       4 df.collate_stamps()
#
# ~/DES/SYNTHETIC/synthetic/synthetic/render/render.py in multi_render(self, nprocess)
#     192         except KeyboardInterrupt:
#     193             print("Caught KeyboardInterrupt, terminating workers")
# --> 194             pool.terminate()
#     195             pool.join()
#     196         else:
#
# ~/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py in terminate(self)
#     546         self._state = TERMINATE
#     547         self._worker_handler._state = TERMINATE
# --> 548         self._terminate()
#     549
#     550     def join(self):
#
# ~/anaconda3/envs/galsim/lib/python3.7/multiprocessing/util.py in __call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     187                 sub_debug('finalizer calling %s with args %s and kwargs %s',
#     188                           self._callback, self._args, self._kwargs)
# --> 189                 res = self._callback(*self._args, **self._kwargs)
#     190             self._weakref = self._callback = self._args = \
#     191                             self._kwargs = self._key = None
#
# ~/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py in _terminate_pool(cls, taskqueue, inqueue, outqueue, pool, worker_handler, task_handler, result_handler, cache)
#     579
#     580         util.debug('helping task handler/workers to finish')
# --> 581         cls._help_stuff_finish(inqueue, task_handler, len(pool))
#     582
#     583         if (not result_handler.is_alive()) and (len(cache) != 0):
#
# ~/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py in _help_stuff_finish(inqueue, task_handler, size)
#     566         inqueue._rlock.acquire()
#     567         while task_handler.is_alive() and inqueue._reader.poll():
# --> 568             inqueue._reader.recv()
#     569             time.sleep(0)
#     570
#
# ~/anaconda3/envs/galsim/lib/python3.7/multiprocessing/connection.py in recv(self)
#     249         self._check_readable()
#     250         buf = self._recv_bytes()
# --> 251         return _ForkingPickler.loads(buf.getbuffer())
#     252
#     253     def poll(self, timeout=0.0):
#
# EOFError: Ran out of input
# Process ForkPoolWorker-297:
# Process ForkPoolWorker-299:
# Process ForkPoolWorker-262:
# Process ForkPoolWorker-240:
# Process ForkPoolWorker-246:
# Process ForkPoolWorker-241:
# Process ForkPoolWorker-251:
# Process ForkPoolWorker-274:
# Process ForkPoolWorker-249:
# Process ForkPoolWorker-272:
# Process ForkPoolWorker-269:
# Process ForkPoolWorker-257:
# Process ForkPoolWorker-275:
# Process ForkPoolWorker-236:
# Process ForkPoolWorker-248:
# Process ForkPoolWorker-266:
# Process ForkPoolWorker-256:
# Process ForkPoolWorker-235:
# Process ForkPoolWorker-273:
# Process ForkPoolWorker-247:
# Process ForkPoolWorker-250:
# Process ForkPoolWorker-239:
# Process ForkPoolWorker-276:
# Process ForkPoolWorker-279:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-232:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 135, in worker
#     completed += 1
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# KeyboardInterrupt
# Traceback (most recent call last):
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# ...
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/connection.py", line 411, in _recv_bytes
#     return self._recv(size)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-234:
# Traceback (most recent call last):
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/home/moon/vargatn/anaconda3/envs/galsim/lib/python3.7/multiprocessing/queues.py", line 354, in get
#     return _ForkingPickler.loads(res)
# KeyboardInterrupt

# %%
galpath = "./ICL/evolving_red_gal.dat"
mstarpath = "./ICL/mstar_des_i03.fit"
jk_profile_root = "./ICL/jacknife_profiles_0.15_rand_back_subtracted_corZ_faintgalsub/jacknife_profile_"

bcg = {
    "size": 32.,
    "g1": 0.1356766444194723,
    "g2":-0.0345231539560347,
    "imag": 17.76,
    "color_gr": 1.36,
    "color_ri": 0.54,
    "color_iz": 0.32,
}
mass = 10**14.45
z = 0.3

di = icl.DrawICL(mass, z, bcg, galpath, mstarpath, jk_profile_root)
di.get_icl()
icl_arrs = [di.flux_g, di.flux_r, di.flux_i, di.flux_z]

# %%
noise_std = 8.36335 / 10
noise = np.random.normal(scale=noise_std, size=(5000, 5000))

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
cc = df.canvas.array + 0.001
ax.imshow(np.arcsinh(cc) / cc, cmap=plt.cm.gray_r)
ax.set_xlabel("X [pix]")
ax.set_ylabel("Y [pix]")

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
cc = df.canvas.array + noise + icl_arrs[2]
cc = cc[2000:3000, 2000:3000]
ax.imshow(image.asinh_scale(cc*0.01, 0.12) * 2, cmap=plt.cm.gray_r)
ax.set_xlabel("X [pix]")
ax.set_ylabel("Y [pix]")
fig.savefig("iband_grayscale.png")

# %% [markdown]
# # Estimating shear in the image

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
cc = df.canvas.array
cc = cc[2000:3000, 2000:3000]
ax.imshow(asinh_scale(cc*0.01, 0.12) * 2, cmap=plt.cm.gray_r)
ax.set_xlabel("X [pix]")
ax.set_ylabel("Y [pix]")
# fig.savefig("iband_grayscale.png")
# Out:
# Text(0, 0.5, 'Y [pix]')

# %%
class ExtractShear(object):
    def __init__(self, drawer):
        self.drawer = drawer
        self.raw_stamps = self.drawer.stamps
        self.image_epsf = self.drawer.image_epsf
        self.BADVAL = -9999
        
    def extract_stamps(self, size=32):
        self.stamps = []
        
        half_size = size // 2
        
        for i, stamp in enumerate(self.raw_stamps):
            bounds = stamp.bounds
            cen = bounds.center
            bb = galsim.bounds.BoundsI(cen.x - half_size,
                                       cen.x + half_size - 1,
                                       cen.y - half_size,
                                       cen.y + half_size - 1)
            self.stamps.append(self.drawer.canvas[bb])
    
    def estimate_shear(self, sky_var=0, shear_est="KSB", which="canvas"):
        """
        shear modes = REGAUSS’, ‘LINEAR’, ‘BJ’, or ‘KSB’
        which is raw or canvas, default to canvas
        """
        
        stamps = self.raw_stamps
        if which == "canvas":
            stamps = self.stamps
        
        self.logs = []
        self.shears = []
        self.success = []
        self.fluxes = []
        self.shears_error = []
        for i, im in enumerate(stamps):
            try:
                res = galsim.hsm.EstimateShear(im, self.image_epsf, shear_est=shear_est, sky_var=sky_var)
                self.logs.append(res)
                
                tmp = np.array([res.corrected_g1, res.corrected_g2])
                
                self.shears.append(tmp)
                self.fluxes.append(res.moments_amp * (self.drawer.pixel_scale)**2)
                self.shears_error.append(res.corrected_shape_err)
                self.success.append(True)
#                 print("here")
            except:
                self.logs.append(None)
                self.fluxes.append(None)
                tmp = np.array([self.BADVAL, self.BADVAL])
                self.shears.append(tmp)
                self.shears_error.append(None)
                self.success.append(False)
                
                
               
        self.fluxes = np.array(self.fluxes)
        self.shears = np.array(self.shears)
        self.success = np.array(self.success)
        self.shears_error = np.array(self.shears_error)

# %%
noise_var = noise_std**2

# %%
es = ExtractShear(df)
es.extract_stamps()
es.estimate_shear(sky_var=noise_var, shear_est="KSB")

# %%
es.shears_error
# Out:
# array([0.0030990394297987223, 0.0036066484171897173, 0.008870688267052174,
#        ..., 0.16856108605861664, 0.44488629698753357, 0.10730892419815063],
#       dtype=object)

# %%
(1. / es.shears_error[es.success])
# Out:
# array([322.68063141905503, 277.26572826835036, 112.73082424891827, ...,
#        5.932567375914111, 2.247765343125463, 9.318889435080498],
#       dtype=object)

# %%
flag = (catalog["MAG_I"] > 19) * (catalog["MAG_I"]) < 22 * es.success

# %%
np.average(es.shears[flag, 0])
# Out:
# -0.016336677885969885

# %%
np.average(es.shears[flag, 1])
# Out:
# 0.03870027283237487

# %%
np.average(es.shears[flag, 0], weights=1 / es.shears_error[flag])
# Out:
# -0.020267105384069263

# %%
es.shears_error[flag].mean()
# Out:
# 0.04449300202374424

# %%
np.average(np.abs(es.shears[flag, 0]), weights=es.shears_error[flag])
# Out:
# 0.15357325146273773

# %%
np.average(np.abs(es.shears[flag, 1] - catalog["G2"][flag]), weights=es.shears_error[flag])
# Out:
# 0.20856628318365186

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

val1 = catalog["MAG_I"][es.success]
val2 = np.abs(es.shears[es.success, 0] - catalog["G1"][es.success])
ax.scatter(val1, val2, s=es.shears_error[es.success])
ax.set_ylim(0.0004, 4)
ax.set_yscale("log")
ax.axhline(0.05, color="red")
# ax.set_xlabel("True MAG i")
# ax.set_ylabel("$\delta$ MAG (measured - true) / true")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-bcff2bacd4c7> in <module>
#       4 val1 = catalog["MAG_I"][es.success]
#       5 val2 = np.abs(es.shears[es.success, 0] - catalog["G1"][es.success])
# ----> 6 ax.scatter(val1, val2, s=es.shears_error[es.success])
#       7 ax.set_ylim(0.0004, 4)
#       8 ax.set_yscale("log")
#
# ~/anaconda3/envs/galsim/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/galsim/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4496                 offsets=offsets,
#    4497                 transOffset=kwargs.pop('transform', self.transData),
# -> 4498                 alpha=alpha
#    4499                 )
#    4500         collection.set_transform(mtransforms.IdentityTransform())
#
# ~/anaconda3/envs/galsim/lib/python3.7/site-packages/matplotlib/collections.py in __init__(self, paths, sizes, **kwargs)
#     883         Collection.__init__(self, **kwargs)
#     884         self.set_paths(paths)
# --> 885         self.set_sizes(sizes)
#     886         self.stale = True
#     887
#
# ~/anaconda3/envs/galsim/lib/python3.7/site-packages/matplotlib/collections.py in set_sizes(self, sizes, dpi)
#     855             self._sizes = np.asarray(sizes)
#     856             self._transforms = np.zeros((len(self._sizes), 3, 3))
# --> 857             scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
#     858             self._transforms[:, 0, 0] = scale
#     859             self._transforms[:, 1, 1] = scale
#
# AttributeError: 'float' object has no attribute 'sqrt'
