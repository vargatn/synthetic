# %%
import numpy as np
import pandas as pd

from importlib import reload

import synthetic.render.generator as gen

import matplotlib.pyplot as plt
# %matplotlib inline

import multiprocessing as mp

import sys
import os
import math
import logging
import time
import galsim
import fitsio as fio

import ngmix

import synthetic.render.render as render
import synthetic.render.icl as icl
import images

# %% [markdown]
# # simple image

# %%
catalog_path = '/e/ocean1/users/vargatn/DES/SIM_DATA/SKY_MODEL_EPSILON/res_clust_v2_z0l0/epsilon_clust_v8-z0l0_15000_000.fits'
catalog = fio.read(catalog_path)
catalog_cluster = catalog[catalog['LOC'] == 1]
catalog_field = catalog[catalog['LOC'] == 0]

# %%
reload(render)
# Out:
# <module 'synthetic.render.render' from '/home/moon/vargatn/DES/SYNTHETIC/synthetic/synthetic/render/render.py'>

# %%
df = render.DrawField(5000, catalog_cluster, band="i")

# %%
df.prepare()
df.make_infodicts()
df.multi_render(10)
df.collate_stamps()
# Out:
# starting xshear calculations in 10 processes

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
cc = df.canvas.array + 0.001
ax.imshow(np.arcsinh(cc) / cc, cmap=plt.cm.gray_r)

# %% [markdown]
# # Estimate shear

# %%
class ExtractShear(object):
    def __init__(self, drawer):
        self.drawer = drawer
        self.raw_stamps = self.drawer.stamps
        self.epsf = self.drawer.image_epsf
        
    def extract_stamps(self, size=16):
        self.stamps = []
        
        half_size = size // 2
        
        for i, stamp in enumerate(self.raw_stamps):
            bounds = stamp.bounds
            cen = bounds.center
            bb = galsim.bounds.BoundsI(cen.x - half_size, cen.x + half_size, cen.y - half_size, cen.y + half_size)
            self.stamps.append(self.drawer.canvas[bb])
    
    def estimate_shear(self, which="canvas"):
        """which is raw or canvas, default to canvas"""
        
        stamps = self.raw_stamps
        if which == "canvas":
            stamps = self.stamps
        
        for i, stamp in (enumerate):

# %%
es = ExtractShear(df)

# %%
es.extract_stamps()

# %%
plt.imshow(es.stamps[0].array)

# %%
plt.imshow(es.raw_stamps[0].array)

# %%
im = df.stamps[1]

# %%
size = 16
cen = im.bounds.center

# %%
cen + size
# Out:
# galsim.PositionI(x=2542, y=2526)

# %%
cen.x
# Out:
# 2542

# %%
xmin, xmax, ymin, ymax

# %%
bb.xmax - bb.xmin
# Out:
# 32

# %%
bb.ymax - bb.ymin
# Out:
# 32

# %%
bb.area()
# Out:
# 1089

# %%
im.bounds.area()
# Out:
# 13924

# %%
image_epsf = df.psf.drawImage(scale=df.pixel_scale)

# %%
results = galsim.hsm.EstimateShear(im, image_epsf)

# %%
results
# Out:
# galsim.hsm.ShapeData(image_bounds=galsim.BoundsI(xmin=2483, xmax=2600, ymin=2467, ymax=2584), moments_status=0, observed_shape=galsim.Shear((0.22987564847265818+0.2185096536633462j)), moments_sigma=3.1282401084899902, moments_amp=50207.1171875, moments_rho4=2.1890093809661306, moments_n_iter=25, correction_status=0, corrected_e1=0.5355886816978455, corrected_e2=0.5090930461883545, meas_type='e', corrected_shape_err=0.0, correction_method='REGAUSS', resolution_factor=0.817931592464447, psf_sigma=1.4765410423278809, psf_shape=galsim.Shear((-3.240654855574121e-09+1.7542138852633116e-09j)))

# %%
results.observed_shape.e1, results.observed_shape.e2, results.moments_sigma
# Out:
# (0.4177319407463074, 0.39707756042480463, 3.1282401084899902)

# %%
res = im.FindAdaptiveMom()

# %%
res
# Out:
# galsim.hsm.ShapeData(image_bounds=galsim.BoundsI(xmin=2336, xmax=2667, ymin=2336, ymax=2667), moments_status=0, observed_shape=galsim.Shear((0.08010915335372391-0.02038503442554799j)), moments_sigma=2.875323534011841, moments_amp=50007.25, moments_centroid=galsim.PositionD(x=2501.4999987253263, y=2501.4999999443494), moments_rho4=2.4315299657446134, moments_n_iter=38, correction_status=-10)
