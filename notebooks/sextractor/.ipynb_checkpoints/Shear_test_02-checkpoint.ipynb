# %%
import numpy as np
import pandas as pd

from importlib import reload
import copy
import synthetic.render.generator as gen

import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

import multiprocessing as mp

import sys
import os
import math
import logging
import time
import galsim
import fitsio as fio

import ngmix

import synthetic.render.render as render
import synthetic.render.icl as icl
import images

# %%
catalog_path = '/e/ocean1/users/vargatn/DES/SIM_DATA/SKY_MODEL_EPSILON/res_clust_v2_z0l0/epsilon_clust_v8-z0l0_15000_000.fits'
data = fio.read(catalog_path)
catalog_cluster = data[data['LOC'] == 1]
catalog_field = data[data['LOC'] == 0]

# %%
catalog = np.hstack((catalog_cluster, catalog_field))
catalog = np.hstack((catalog_cluster, catalog_field))
catalog['G1'] = 0.3
catalog['G2'] = -0.2

# %%
df = render.DrawField(5000, catalog, band="i")
df.prepare()
df.make_infodicts()
df.multi_render(100)
df.collate_stamps()
# Out:
# starting xshear calculations in 100 processes

# %%
noise_std = 8.36335 / 4
noise = np.random.normal(scale=noise_std, size=(5000, 5000))

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
#cc = icl_arrs[2]
cc = df.canvas.array + noise
cc = cc[2100:2900, 2100:2900]
ax.imshow(images.asinh_scale(cc*0.01, 0.12) * 2, cmap=plt.cm.gray_r)
ax.set_xlabel("X [pix]")
ax.set_ylabel("Y [pix]")
# Out:
# Text(0, 0.5, 'Y [pix]')

# %%
arr = df.canvas.array + noise
#arr = arr[2100:2900, 2100:2900]
fio.write("test.fits", arr, clobber=True)

# %%
cat = fio.read("test.cat.fits")
seg = fio.read("seg.fits")

# %%
# sel = cat['FLAGS'] == 0

# %%
ids = cat['NUMBER']
cens = np.vstack((cat['X_IMAGE'], cat['Y_IMAGE'])).T

# %%
class Shear2(object):
    def __init__(self, canvas, image_epsf, maskmap):
        self.canvas = canvas.copy()
        self.image_epsf = image_epsf
        self.BADVAL = -9999
        self.maskmap = galsim.ImageI(maskmap)
        
    def extract_stamps(self, centers, imasks, size=32):
        half_size = size // 2
        self.stamps = []
        self.masks = []
        for i in np.arange(len(centers)):
            cen = centers[i]
            bb = galsim.bounds.BoundsI(np.round(cen[0]) - half_size,
                                       np.round(cen[0]) + half_size - 1,
                                       np.round(cen[1]) - half_size,
                                       np.round(cen[1]) + half_size - 1)
            stamp = self.canvas[bb]
#             mask = self.maskmap[bb]
#             mm = (mask.array != 0) & (mask.array != imasks[i])
#             mm = (mask.array != imasks[i])
#             mask.array[mm] = 1
            
#             stamp.array[mm] = 0
            
#             self.masks.append(mask)
            self.stamps.append(stamp)


    def estimate_shear(self, sky_var=0, shear_est="KSB", which="canvas"):
        """
        shear modes = REGAUSS’, ‘LINEAR’, ‘BJ’, or ‘KSB’
        which is raw or canvas, default to canvas
        """
        
        stamps = self.stamps
        if which == "canvas":
            stamps = self.stamps
        
        self.logs = []
        self.shears = []
        self.success = []
        self.fluxes = []
        self.shears_error = []
        for i, im in enumerate(stamps[:1000]):
            try:
                res = galsim.hsm.EstimateShear(im, self.image_epsf, shear_est=shear_est, sky_var=sky_var)
                self.logs.append(res)
                
                tmp = np.array([res.corrected_g1, res.corrected_g2])
                
                self.shears.append(tmp)
                self.fluxes.append(res.moments_amp * (self.drawer.pixel_scale)**2)
                self.shears_error.append(res.corrected_shape_err)
                self.success.append(True)
#                 print("here")
            except:
                self.logs.append(None)
                self.fluxes.append(None)
                tmp = np.array([self.BADVAL, self.BADVAL])
                self.shears.append(tmp)
                self.shears_error.append(None)
                self.success.append(False)
                
                
               
        self.fluxes = np.array(self.fluxes)
        self.shears = np.array(self.shears)
        self.success = np.array(self.success)
        self.shears_error = np.array(self.shears_error)

# %%
class Shear(object):
    def __init__(self, canvas, image_epsf, maskmap):
        self.canvas = canvas.copy()
        self.image_epsf = image_epsf
        self.BADVAL = -9999
        self.maskmap = galsim.ImageI(maskmap).copy()
        
    def extract_stamps(self, centers, imasks, size=32):
        half_size = size // 2
        self.stamps = []
        self.masks = []
        for i in np.arange(len(centers)):
            cen = centers[i]
            bb = galsim.bounds.BoundsI(np.round(cen[0]) - half_size,
                                       np.round(cen[0]) + half_size - 1,
                                       np.round(cen[1]) - half_size,
                                       np.round(cen[1]) + half_size - 1)
            stamp = self.canvas[bb].array.copy()
            mask = self.maskmap[bb].array.copy()
#             mm = (mask.array != imasks[i]) & (mask.array != 0)
            mm = (mask != imasks[i]) & (mask != 0)
            muniques = np.unique(mask)
#             print(np.unique(mask), imasks[i], bb)
            stamp[mm] = 0
            mask[mm] = 0
#             
            self.masks.append(self.maskmap[bb].array.copy())
            self.stamps.append(stamp)


    def estimate_shear(self, sky_var=0, shear_est="KSB", which="canvas"):
        """
        shear modes = REGAUSS’, ‘LINEAR’, ‘BJ’, or ‘KSB’
        which is raw or canvas, default to canvas
        """
        
#         stamps = self.raw_stamps
        if which == "canvas":
            stamps = self.stamps
        
        self.logs = []
        self.shears = []
        self.success = []
        self.fluxes = []
        self.shears_error = []
        for i, im in enumerate(stamps):
            try:
                res = galsim.hsm.EstimateShear(im, self.image_epsf, shear_est=shear_est, sky_var=sky_var)
                self.logs.append(res)
                
                tmp = np.array([res.corrected_g1, res.corrected_g2])
                
                self.shears.append(tmp)
                self.fluxes.append(res.moments_amp * (self.drawer.pixel_scale)**2)
                self.shears_error.append(res.corrected_shape_err)
                self.success.append(True)
#                 print("here")
            except:
                self.logs.append(None)
                self.fluxes.append(None)
                tmp = np.array([self.BADVAL, self.BADVAL])
                self.shears.append(tmp)
                self.shears_error.append(None)
                self.success.append(False)
                
                
               
        self.fluxes = np.array(self.fluxes)
        self.shears = np.array(self.shears)
        self.success = np.array(self.success)
        self.shears_error = np.array(self.shears_error)

# %%
sc2 = Shear2(df.canvas, df.image_epsf, seg)
sc2.extract_stamps(cens, ids, size=32)
sc2.estimate_shear(sky_var=noise_std**2)

# %%
sc = Shear(df.canvas, df.image_epsf, seg)
sc.extract_stamps(cens, imasks=ids, size=32)
sc.estimate_shear(sky_var=noise_std**2)

# %%
sc.fluxes.max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-530-fed071194246> in <module>
# ----> 1 sc.fluxes.max()
#
# ~/anaconda3/envs/galsim/lib/python3.7/site-packages/numpy/core/_methods.py in _amax(a, axis, out, keepdims, initial)
#      26 def _amax(a, axis=None, out=None, keepdims=False,
#      27           initial=_NoValue):
# ---> 28     return umr_maximum(a, axis, None, out, keepdims, initial)
#      29
#      30 def _amin(a, axis=None, out=None, keepdims=False,
#
# TypeError: '>=' not supported between instances of 'NoneType' and 'NoneType'

# %%
fig, axarr = plt.subplots(ncols=2, figsize=(12, 6))



ax = axarr[0]
# ax.set_title("each galaxy has the same shape, different sizes and mags")
ii1 = sc.success
ii2 = sc2.success

# val1 = catalog["MAG_I"][ii1]
# val2 = es.shears[ii1, 0]
# ax.scatter(val1, val2, color="C1", s=3, label="z > 0.4")

# val1 = catalog["MAG_I"][ii2]
# val2 = es.shears[ii2, 0]
# ax.scatter(val1, val2, color="C0", s=3, label="z < 0.4")
# # ax.set_yscale("log")
# ax.set_ylim(-0.3, 0.4)
# ax.set_xlabel("True MAG i")
# ax.axhline(0.05, color="magenta", ls="--", lw=2)
# ax.axhline(-0.02, color="blue", ls="--", lw=2)
# ax.set_ylabel("G1")
# ax.legend()

# ax = axarr[1]
# ii1 = (tcat['Z'] < 0.4) * es.success
# ii2 = (tcat['Z'] > 0.4) * es.success

# val1 = catalog["MAG_I"][ii1]
# val2 = es.shears[ii1, 1]
# ax.scatter(val1, val2, color="C1", s=3, label="z > 0.4")

# val1 = catalog["MAG_I"][ii2]
# val2 = es.shears[ii2, 1]
# ax.scatter(val1, val2, color="C0", s=3, label="z < 0.4")
# # ax.set_yscale("log")
# ax.set_ylim(-0.3, 0.4)
# ax.set_xlabel("True MAG i")
# ax.axhline(-0.03, color="magenta", ls="--", lw=2)
# ax.axhline(0.02, color="blue", ls="--", lw=2)
# ax.set_ylabel("G1")
# ax.legend()
# ax.set_ylabel("G2")

# %%
fig, axarr = plt.subplots(4, 4, figsize=(12, 12))

for i, ax in enumerate(axarr.flatten()):
    cc = sc.stamps[i]
    ax.imshow(images.asinh_scale(cc*0.01, 0.12) * 2, cmap=plt.cm.terrain_r,
              norm=mpl.colors.Normalize())

fig.text(0.4, 0.9, "with masking", fontsize=16)
fig.savefig("postage_with_masking_v1.png")

# %%
fig, axarr = plt.subplots(4, 4, figsize=(12, 12))

for i, ax in enumerate(axarr.flatten()):
    cc = sc.masks[i]
    ax.imshow(cc, cmap=plt.cm.terrain_r,
              norm=mpl.colors.Normalize())
fig.text(0.4, 0.9, "sextractor segmentation masks", fontsize=16)
fig.savefig("postage_mask_v1.png")

# %%
fig, axarr = plt.subplots(4, 4, figsize=(12, 12))

for i, ax in enumerate(axarr.flatten()):
    cc = sc2.stamps[i].array
    ax.imshow(images.asinh_scale(cc*0.01, 0.12) * 2, cmap=plt.cm.terrain_r,
              norm=mpl.colors.Normalize())
fig.text(0.4, 0.9, "without masking", fontsize=16)
fig.savefig("postage_without_masking_v1.png")

# %%
sc.success
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-510-d4ee1e355a3e> in <module>
# ----> 1 sc.success
#
# AttributeError: 'Shear' object has no attribute 'success'

# %%
fig, axarr = plt.subplots(ncols=2, figsize=(12, 6))



ax = axarr[0]
# ax.set_title("each galaxy has the same shape, different sizes and mags")
ii1 = sc.success
ii2 = sc2.success

# val1 = catalog["MAG_I"][ii1]
# val2 = es.shears[ii1, 0]
# ax.scatter(val1, val2, color="C1", s=3, label="z > 0.4")

# val1 = catalog["MAG_I"][ii2]
# val2 = es.shears[ii2, 0]
# ax.scatter(val1, val2, color="C0", s=3, label="z < 0.4")
# # ax.set_yscale("log")
# ax.set_ylim(-0.3, 0.4)
# ax.set_xlabel("True MAG i")
# ax.axhline(0.05, color="magenta", ls="--", lw=2)
# ax.axhline(-0.02, color="blue", ls="--", lw=2)
# ax.set_ylabel("G1")
# ax.legend()

# ax = axarr[1]
# ii1 = (tcat['Z'] < 0.4) * es.success
# ii2 = (tcat['Z'] > 0.4) * es.success

# val1 = catalog["MAG_I"][ii1]
# val2 = es.shears[ii1, 1]
# ax.scatter(val1, val2, color="C1", s=3, label="z > 0.4")

# val1 = catalog["MAG_I"][ii2]
# val2 = es.shears[ii2, 1]
# ax.scatter(val1, val2, color="C0", s=3, label="z < 0.4")
# # ax.set_yscale("log")
# ax.set_ylim(-0.3, 0.4)
# ax.set_xlabel("True MAG i")
# ax.axhline(-0.03, color="magenta", ls="--", lw=2)
# ax.axhline(0.02, color="blue", ls="--", lw=2)
# ax.set_ylabel("G1")
# ax.legend()
# ax.set_ylabel("G2")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-506-90247d45bae5> in <module>
#       5 ax = axarr[0]
#       6 # ax.set_title("each galaxy has the same shape, different sizes and mags")
# ----> 7 ii1 = sc.success
#       8 ii2 = sc2.success
#       9
#
# AttributeError: 'Shear' object has no attribute 'success'

# %%
mask = sc.masks[3].array.copy()
print(np.unique(mask))
stamp = sc.stamps[3].array.copy()
mm = (mask != 6) & (mask != 0)
stamp[mm] = 0
# Out:
# [ 0  6 13 25]

# %%
ids[1]
# Out:
# 4

# %%
plt.imshow(stamp)
